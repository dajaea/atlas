# %% [markdown]
# import gensim
# import gensim.corpora as corpora
# from gensim.corpora import Dictionary
# from gensim.models.coherencemodel import CoherenceModel
# from gensim.models.ldamodel import LdaModel
#
# from pprint import pprint
#
# import spacy
#
# import pickle
# import re
# import pyLDAvis
# import pyLDAvis.gensim
#
# import matplotlib.pyplot as plt
# import pandas as pd
# ___
#
# import numpy
# numpy.random.bit_generator = numpy.random._bit_generator

# %% [markdown]
# ### fully uninstalled, reinstalled numpy, restarted kernel, finally
# import gensim
# from gensim import corpora
# #### about 18 cells down runs, creates:
# ###### Dictionary(54130 unique tokens: ['0', '0frac', '0mathbf', '0ttfrac', '1']...)

# %% [markdown]
# import numpy
# numpy.random.bit_generator = numpy.random._bit_generator

# %% [markdown]
# import numpy as np
# rng = np.random.default_rng(12345)
# print(rng)
# Generator(PCG64)
# rfloat = rng.random()
# rfloat
# 0.22733602246716966
# type(rfloat)

# %% [markdown]
# random.Generator.bit_generator

# %% [markdown]
# with help from
#
# https://shichaoji.com/tag/topic-modeling-python-lda-visualization-gensim-pyldavis-nltk/

# %%
from helper import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-16a03b09fed6> in <module>
# ----> 1 from helper import *
#
# ModuleNotFoundError: No module named 'helper'

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\feature_extraction\image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:284: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_Gram=True, verbose=0,
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1101: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1127: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1362: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1602: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:1738: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

stopwords = set(stopwords.words('english'))
punctuation = set(string.punctuation) 
lemmatize = WordNetLemmatizer()

def cleaning(article):
    one = " ".join([i for i in article.lower().split() if i not in stopwords])
    two = "".join(i for i in one if i not in punctuation)
    three = " ".join(lemmatize.lemmatize(i) for i in two.split())
    return three

# %%
import pandas as pd
import numpy as np
import re
import json
import glob

# %%
folder = (glob.glob('../data/english_topic_full_content/*'))

# %%
article_list = []
for file in folder:
    with open(file, 'r') as f:
        article = json.load(f)
    article_list.append(article)

# %%
articles = pd.DataFrame(article_list).replace(r'^\s*$', np.nan, regex = True)
articles.info()

#ignore error - dataframe still runs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-76c1f0298af4> in <module>
#       1 articles = pd.DataFrame(article_list).replace(r'^\s*$', np.nan, regex = True)
# ----> 2 articles.info()
#       3
#       4 #ignore error - dataframe still runs
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2555                 if "object" in counts or self.index._is_memory_usage_qualified():
#    2556                     size_qualifier = "+"
# -> 2557             mem_usage = self.memory_usage(index=True, deep=deep).sum()
#    2558             lines.append(
#    2559                 "memory usage: {mem}\n".format(
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in memory_usage(self, index, deep)
#    2653         )
#    2654         if index:
# -> 2655             result = Series(self.index.memory_usage(deep=deep), index=["Index"]).append(
#    2656                 result
#    2657             )
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309                     data = data.copy()
#     310             else:
# --> 311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
#     313                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710                 value = maybe_cast_to_datetime(value, dtype)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#     714         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231                 value = ensure_str(value)
#    1232
# -> 1233         subarr = np.empty(length, dtype=dtype)
#    1234         subarr.fill(value)
#    1235
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
articles = articles.dropna()

# %%
articles.head(200)
# Out:
#             topic english_title  \
# 0    Acceleration  Acceleration
# 1      acceptance    Acceptance
# 4       Aerospace     Aerospace
# 5    Agricultural   Agriculture
# 6     Agriculture   Agriculture
# ..            ...           ...
# 262      Shopping      Shopping
# 264        Social        Social
# 265       Society       Society
# 266     Sociology     Sociology
# 267      software      Software
#
#                                                english
# 0    In mechanics, acceleration is the rate of chan...
# 1    Acceptance in human psychology is a person's a...
# 4    Aerospace is a term used to collectively refer...
# 5    Agriculture is the science, art and practice o...
# 6    Agriculture is the science, art and practice o...
# ..                                                 ...
# 262  Shopping is an activity in which a customer br...
# 264  Social organisms, including humans, live colle...
# 265  A society is a group of individuals involved i...
# 266  Sociology is the study of society, human socia...
# 267  Software is a collection of instructions and d...
#
# [200 rows x 3 columns]

# %%
text = articles.applymap(cleaning)['english']
text_list = [i.split() for i in text]
len(text_list)
# Out:
# 243

# %%
text_list[0]
# Out:
# ['mechanic',
#  'acceleration',
#  'rate',
#  'change',
#  'velocity',
#  'object',
#  'respect',
#  'time',
#  'acceleration',
#  'vector',
#  'quantity',
#  'in',
#  'magnitude',
#  'direction',
#  'orientation',
#  'object',
#  'acceleration',
#  'given',
#  'orientation',
#  'net',
#  'force',
#  'acting',
#  'object',
#  'magnitude',
#  'object',
#  'acceleration',
#  'described',
#  'newton',
#  'second',
#  'law',
#  'combined',
#  'effect',
#  'two',
#  'cause',
#  'net',
#  'balance',
#  'external',
#  'force',
#  'acting',
#  'onto',
#  'object',
#  '—',
#  'magnitude',
#  'directly',
#  'proportional',
#  'net',
#  'resulting',
#  'force',
#  'object',
#  'mass',
#  'depending',
#  'material',
#  'made',
#  '—',
#  'magnitude',
#  'inversely',
#  'proportional',
#  'object',
#  'massthe',
#  'si',
#  'unit',
#  'acceleration',
#  'metre',
#  'per',
#  'second',
#  'squared',
#  'm⋅s−2',
#  '2',
#  'displaystyle',
#  'tfrac',
#  'operatorname',
#  'm',
#  'operatorname',
#  's',
#  '2',
#  'example',
#  'vehicle',
#  'start',
#  'standstill',
#  'zero',
#  'velocity',
#  'inertial',
#  'frame',
#  'reference',
#  'travel',
#  'straight',
#  'line',
#  'increasing',
#  'speed',
#  'accelerating',
#  'direction',
#  'travel',
#  'vehicle',
#  'turn',
#  'acceleration',
#  'occurs',
#  'toward',
#  'new',
#  'direction',
#  'change',
#  'motion',
#  'vector',
#  'acceleration',
#  'vehicle',
#  'current',
#  'direction',
#  'motion',
#  'called',
#  'linear',
#  'or',
#  'tangential',
#  'circular',
#  'motion',
#  'acceleration',
#  'reaction',
#  'passenger',
#  'board',
#  'experience',
#  'force',
#  'pushing',
#  'back',
#  'seat',
#  'changing',
#  'direction',
#  'effecting',
#  'acceleration',
#  'called',
#  'radial',
#  'or',
#  'orthogonal',
#  'circular',
#  'motion',
#  'acceleration',
#  'reaction',
#  'passenger',
#  'experience',
#  'centrifugal',
#  'force',
#  'speed',
#  'vehicle',
#  'decrease',
#  'acceleration',
#  'opposite',
#  'direction',
#  'mathematically',
#  'negative',
#  'sometimes',
#  'called',
#  'deceleration',
#  'passenger',
#  'experience',
#  'reaction',
#  'deceleration',
#  'inertial',
#  'force',
#  'pushing',
#  'forward',
#  'negative',
#  'acceleration',
#  'often',
#  'achieved',
#  'retrorocket',
#  'burning',
#  'spacecraft',
#  'acceleration',
#  'deceleration',
#  'treated',
#  'same',
#  'change',
#  'velocity',
#  'acceleration',
#  'tangential',
#  'radial',
#  'deceleration',
#  'felt',
#  'passenger',
#  'relative',
#  'differential',
#  'velocity',
#  'neutralized',
#  'reference',
#  'vehicle',
#  'addt',
#  'v',
#  'definition',
#  'property',
#  'average',
#  'acceleration',
#  'object',
#  'average',
#  'acceleration',
#  'period',
#  'time',
#  'change',
#  'velocity',
#  'δ',
#  'v',
#  'displaystyle',
#  'delta',
#  'mathbf',
#  'v',
#  'divided',
#  'duration',
#  'period',
#  'δ',
#  'displaystyle',
#  'delta',
#  't',
#  'mathematically',
#  '¯',
#  'δ',
#  'v',
#  'δ',
#  'displaystyle',
#  'bar',
#  'mathbf',
#  'a',
#  'frac',
#  'delta',
#  'mathbf',
#  'v',
#  'delta',
#  't',
#  'instantaneous',
#  'acceleration',
#  'instantaneous',
#  'acceleration',
#  'meanwhile',
#  'limit',
#  'average',
#  'acceleration',
#  'infinitesimal',
#  'interval',
#  'time',
#  'term',
#  'calculus',
#  'instantaneous',
#  'acceleration',
#  'derivative',
#  'velocity',
#  'vector',
#  'respect',
#  'time',
#  'lim',
#  'δ',
#  '→',
#  '0',
#  'δ',
#  'v',
#  'δ',
#  'v',
#  'displaystyle',
#  'mathbf',
#  'a',
#  'lim',
#  'delta',
#  'tto',
#  '0frac',
#  'delta',
#  'mathbf',
#  'v',
#  'delta',
#  'tfrac',
#  'dmathbf',
#  'v',
#  'dt',
#  'acceleration',
#  'defined',
#  'derivative',
#  'velocity',
#  'v',
#  'respect',
#  'time',
#  'velocity',
#  'defined',
#  'derivative',
#  'position',
#  'x',
#  'respect',
#  'time',
#  'acceleration',
#  'thought',
#  'second',
#  'derivative',
#  'x',
#  'respect',
#  't',
#  'v',
#  '2',
#  'x',
#  '2',
#  'displaystyle',
#  'mathbf',
#  'a',
#  'frac',
#  'dmathbf',
#  'v',
#  'dtfrac',
#  'd2mathbf',
#  'x',
#  'dt2',
#  'here',
#  'elsewhere',
#  'motion',
#  'straight',
#  'line',
#  'vector',
#  'quantity',
#  'substituted',
#  'scalar',
#  'equation',
#  'fundamental',
#  'theorem',
#  'calculus',
#  'seen',
#  'integral',
#  'acceleration',
#  'function',
#  'at',
#  'velocity',
#  'function',
#  'vt',
#  'is',
#  'area',
#  'curve',
#  'acceleration',
#  'v',
#  'time',
#  'a',
#  'v',
#  't',
#  'graph',
#  'corresponds',
#  'velocity',
#  'v',
#  '∫',
#  'displaystyle',
#  'mathbf',
#  'v',
#  'int',
#  'mathbf',
#  'a',
#  'dt',
#  'likewise',
#  'integral',
#  'jerk',
#  'function',
#  'jt',
#  'derivative',
#  'acceleration',
#  'function',
#  'used',
#  'find',
#  'acceleration',
#  'certain',
#  'time',
#  '∫',
#  'j',
#  'displaystyle',
#  'mathbf',
#  'a',
#  'int',
#  'mathbf',
#  'j',
#  'dt',
#  'unit',
#  'acceleration',
#  'dimension',
#  'velocity',
#  'lt',
#  'divided',
#  'time',
#  'ie',
#  'l',
#  't−2',
#  'si',
#  'unit',
#  'acceleration',
#  'metre',
#  'per',
#  'second',
#  'squared',
#  'm',
#  's−2',
#  'metre',
#  'per',
#  'second',
#  'per',
#  'second',
#  'velocity',
#  'metre',
#  'per',
#  'second',
#  'change',
#  'acceleration',
#  'value',
#  'every',
#  'second',
#  'form',
#  'object',
#  'moving',
#  'circular',
#  'motion—such',
#  'satellite',
#  'orbiting',
#  'earth—is',
#  'accelerating',
#  'due',
#  'change',
#  'direction',
#  'motion',
#  'although',
#  'speed',
#  'may',
#  'constant',
#  'case',
#  'said',
#  'undergoing',
#  'centripetal',
#  'directed',
#  'towards',
#  'center',
#  'acceleration',
#  'proper',
#  'acceleration',
#  'acceleration',
#  'body',
#  'relative',
#  'freefall',
#  'condition',
#  'measured',
#  'instrument',
#  'called',
#  'accelerometer',
#  'classical',
#  'mechanic',
#  'body',
#  'constant',
#  'mass',
#  'vector',
#  'acceleration',
#  'body',
#  'center',
#  'mass',
#  'proportional',
#  'net',
#  'force',
#  'vector',
#  'ie',
#  'sum',
#  'force',
#  'acting',
#  'newton',
#  'second',
#  'law',
#  'f',
#  '→',
#  'f',
#  'displaystyle',
#  'mathbf',
#  'f',
#  'mmathbf',
#  'a',
#  'quad',
#  'to',
#  'quad',
#  'mathbf',
#  'a',
#  'frac',
#  'mathbf',
#  'f',
#  'm',
#  'f',
#  'net',
#  'force',
#  'acting',
#  'body',
#  'mass',
#  'body',
#  'centerofmass',
#  'acceleration',
#  'speed',
#  'approach',
#  'speed',
#  'light',
#  'relativistic',
#  'effect',
#  'become',
#  'increasingly',
#  'large',
#  'tangential',
#  'centripetal',
#  'acceleration',
#  'velocity',
#  'particle',
#  'moving',
#  'curved',
#  'path',
#  'function',
#  'time',
#  'written',
#  'a',
#  'v',
#  'v',
#  'v',
#  'v',
#  'v',
#  'u',
#  'displaystyle',
#  'mathbf',
#  'v',
#  'tvtfrac',
#  'mathbf',
#  'v',
#  'tvtvtmathbf',
#  'u',
#  'mathrm',
#  't',
#  't',
#  'vt',
#  'equal',
#  'speed',
#  'travel',
#  'along',
#  'path',
#  'u',
#  'v',
#  'v',
#  'displaystyle',
#  'mathbf',
#  'u',
#  'mathrm',
#  't',
#  'frac',
#  'mathbf',
#  'v',
#  'tvt',
#  'unit',
#  'vector',
#  'tangent',
#  'path',
#  'pointing',
#  'direction',
#  'motion',
#  'chosen',
#  'moment',
#  'time',
#  'taking',
#  'account',
#  'changing',
#  'speed',
#  'vt',
#  'changing',
#  'direction',
#  'ut',
#  'acceleration',
#  'particle',
#  'moving',
#  'curved',
#  'path',
#  'written',
#  'using',
#  'chain',
#  'rule',
#  'differentiation',
#  'product',
#  'two',
#  'function',
#  'time',
#  'a',
#  'v',
#  'v',
#  'u',
#  'v',
#  'u',
#  'v',
#  'u',
#  'v',
#  '2',
#  'r',
#  'u',
#  'n',
#  'displaystyle',
#  'beginalignedat3mathbf',
#  'a',
#  'frac',
#  'mathrm',
#  'd',
#  'mathbf',
#  'v',
#  'mathrm',
#  'd',
#  'tfrac',
#  'mathrm',
#  'd',
#  'vmathrm',
#  'd',
#  'tmathbf',
#  'u',
#  'mathrm',
#  't',
#  'vtfrac',
#  'dmathbf',
#  'u',
#  'mathrm',
#  't',
#  'dtfrac',
#  'mathrm',
#  'd',
#  'vmathrm',
#  'd',
#  'tmathbf',
#  'u',
#  'mathrm',
#  't',
#  'frac',
#  'v2rmathbf',
#  'u',
#  'mathrm',
#  'n',
#  'endalignedat',
#  'un',
#  'unit',
#  'inward',
#  'normal',
#  'vector',
#  'particle',
#  'trajectory',
#  'also',
#  'called',
#  'principal',
#  'normal',
#  'r',
#  'instantaneous',
#  'radius',
#  'curvature',
#  'based',
#  'upon',
#  'osculating',
#  'circle',
#  'time',
#  't',
#  'component',
#  'called',
#  'tangential',
#  'acceleration',
#  'normal',
#  'radial',
#  'acceleration',
#  'or',
#  'centripetal',
#  'acceleration',
#  'circular',
#  'motion',
#  'see',
#  'also',
#  'circular',
#  'motion',
#  'centripetal',
#  'force',
#  'geometrical',
#  'analysis',
#  'threedimensional',
#  'space',
#  'curve',
#  'explains',
#  'tangent',
#  'principal',
#  'normal',
#  'binormal',
#  'described',
#  'frenet–serret',
#  'formula',
#  'special',
#  'case',
#  'uniform',
#  'acceleration',
#  'uniform',
#  'constant',
#  'acceleration',
#  'type',
#  'motion',
#  'velocity',
#  'object',
#  'change',
#  'equal',
#  'amount',
#  'every',
#  'equal',
#  'time',
#  'period',
#  'frequently',
#  'cited',
#  'example',
#  'uniform',
#  'acceleration',
#  'object',
#  'free',
#  'fall',
#  'uniform',
#  'gravitational',
#  'field',
#  'acceleration',
#  'falling',
#  'body',
#  'absence',
#  'resistance',
#  'motion',
#  'dependent',
#  'gravitational',
#  'field',
#  'strength',
#  'g',
#  'also',
#  'called',
#  'acceleration',
#  'due',
#  'gravity',
#  'newton',
#  'second',
#  'law',
#  'force',
#  'f',
#  'g',
#  'displaystyle',
#  'mathbf',
#  'fg',
#  'acting',
#  'body',
#  'given',
#  'by',
#  'f',
#  'g',
#  'g',
#  'displaystyle',
#  'mathbf',
#  'fg',
#  'mmathbf',
#  'g',
#  'simple',
#  'analytic',
#  'property',
#  'case',
#  'constant',
#  'acceleration',
#  'simple',
#  'formula',
#  'relating',
#  'displacement',
#  'initial',
#  'timedependent',
#  'velocity',
#  'acceleration',
#  'time',
#  'elapsed',
#  '0',
#  'v',
#  '0',
#  '1',
#  '2',
#  '2',
#  '0',
#  'v',
#  '0',
#  'v',
#  '2',
#  'displaystyle',
#  'mathbf',
#  's',
#  'tmathbf',
#  's',
#  '0mathbf',
#  'v',
#  '0ttfrac',
#  '12mathbf',
#  'a',
#  't2mathbf',
#  's',
#  '0frac',
#  'mathbf',
#  'v',
#  '0mathbf',
#  'v',
#  't2t',
#  'v',
#  'v',
#  '0',
#  'displaystyle',
#  'mathbf',
#  'v',
#  'tmathbf',
#  'v',
#  '0mathbf',
#  'a',
#  't',
#  'v',
#  '2',
#  'v',
#  '0',
#  '2',
#  '2',
#  '⋅',
#  '−',
#  '0',
#  'displaystyle',
#  'v2tv022mathbf',
#  'acdot',
#  'mathbf',
#  's',
#  'tmathbf',
#  's',
#  '0',
#  'displaystyle',
#  't',
#  'elapsed',
#  'time',
#  '0',
#  'displaystyle',
#  'mathbf',
#  's',
#  '0',
#  'initial',
#  'displacement',
#  'origin',
#  'displaystyle',
#  'mathbf',
#  's',
#  't',
#  'displacement',
#  'origin',
#  'time',
#  'displaystyle',
#  't',
#  'v',
#  '0',
#  'displaystyle',
#  'mathbf',
#  'v',
#  '0',
#  'initial',
#  'velocity',
#  'v',
#  'displaystyle',
#  'mathbf',
#  'v',
#  't',
#  'velocity',
#  'time',
#  'displaystyle',
#  't',
#  'displaystyle',
#  'mathbf',
#  'a',
#  'uniform',
#  'rate',
#  'accelerationin',
#  'particular',
#  'motion',
#  'resolved',
#  'two',
#  'orthogonal',
#  'part',
#  'one',
#  'constant',
#  'velocity',
#  'according',
#  'equation',
#  'galileo',
#  'showed',
#  'net',
#  'result',
#  'parabolic',
#  'motion',
#  'describes',
#  'e',
#  'g',
#  'trajectory',
#  'projectile',
#  'vacuum',
#  'near',
#  'surface',
#  'earth',
#  'circular',
#  'motion',
#  'uniform',
#  'circular',
#  'motion',
#  'moving',
#  'constant',
#  'speed',
#  'along',
#  'circular',
#  'path',
#  'particle',
#  'experience',
#  'acceleration',
#  'resulting',
#  'change',
#  'direction',
#  'velocity',
#  'vector',
#  'magnitude',
#  'remains',
#  'constant',
#  'derivative',
#  'location',
#  'point',
#  'curve',
#  'respect',
#  'time',
#  'ie',
#  'velocity',
#  'turn',
#  'always',
#  'exactly',
#  'tangential',
#  'curve',
#  'respectively',
#  'orthogonal',
#  'radius',
#  'point',
#  'since',
#  'uniform',
#  'motion',
#  'velocity',
#  'tangential',
#  'direction',
#  'change',
#  'acceleration',
#  'must',
#  'radial',
#  'direction',
#  'pointing',
#  'center',
#  'circle',
#  'acceleration',
#  'constantly',
#  'change',
#  'direction',
#  'velocity',
#  'tangent',
#  'neighboring',
#  'point',
#  'thereby',
#  'rotating',
#  'velocity',
#  'vector',
#  'along',
#  'circle',
#  '•',
#  'given',
#  'speed',
#  'v',
#  'displaystyle',
#  'v',
#  'magnitude',
#  'geometrically',
#  'caused',
#  'acceleration',
#  'centripetal',
#  'acceleration',
#  'inversely',
#  'proportional',
#  'radius',
#  'r',
#  'displaystyle',
#  'r',
#  'circle',
#  'increase',
#  'square',
#  'speed',
#  'c',
#  'v',
#  '2',
#  'r',
#  'displaystyle',
#  'acfrac',
#  'v2r',
#  '•',
#  'note',
#  'that',
#  'given',
#  'angular',
#  'velocity',
#  'ω',
#  'displaystyle',
#  'omega',
#  'centripetal',
#  'acceleration',
#  'directly',
#  'proportional',
#  'radius',
#  'r',
#  'displaystyle',
#  'r',
#  'due',
#  'dependence',
#  'velocity',
#  'v',
#  'displaystyle',
#  ...]

# %%
from time import time
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO,
                   filename='running.log',filemode='w')

# %%
# Importing Gensim
import gensim
from gensim import corpora

# Creating the term dictionary of our courpus, where every unique term is assigned an index. dictionary = corpora.Dictionary(doc_clean)
dictionary = corpora.Dictionary(text_list)
dictionary.save('dictionary.dict')
print(dictionary)
# Out:
# Dictionary(54130 unique tokens: ['0', '0frac', '0mathbf', '0ttfrac', '1']...)

# %%
# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in text_list]
corpora.MmCorpus.serialize('corpus.mm', doc_term_matrix)

len(doc_term_matrix)
print(doc_term_matrix[100])
# Out:
# [(8, 1), (21, 1), (23, 1), (27, 3), (29, 10), (30, 2), (31, 1), (32, 2), (42, 5), (47, 4), (50, 2), (51, 3), (52, 2), (63, 3), (64, 2), (70, 1), (75, 2), (76, 1), (88, 1), (103, 2), (108, 1), (109, 2), (110, 1), (123, 1), (131, 2), (145, 1), (147, 6), (153, 1), (155, 2), (160, 1), (164, 5), (168, 1), (177, 1), (180, 1), (191, 1), (193, 1), (199, 2), (213, 1), (215, 5), (223, 1), (229, 3), (233, 1), (237, 8), (254, 2), (261, 3), (268, 3), (269, 1), (272, 9), (274, 6), (281, 1), (286, 4), (288, 3), (292, 2), (300, 2), (303, 2), (316, 1), (328, 3), (329, 1), (335, 1), (343, 1), (348, 1), (349, 1), (350, 3), (352, 2), (353, 2), (374, 8), (380, 1), (383, 17), (394, 3), (399, 3), (401, 1), (408, 4), (409, 1), (419, 3), (429, 2), (468, 2), (477, 1), (482, 3), (492, 1), (494, 6), (496, 1), (505, 2), (518, 2), (520, 1), (522, 1), (532, 4), (546, 2), (556, 2), (561, 1), (564, 2), (565, 1), (571, 1), (572, 1), (573, 1), (575, 1), (576, 2), (584, 1), (585, 2), (608, 3), (609, 2), (610, 1), (625, 1), (644, 3), (647, 6), (656, 2), (658, 1), (661, 1), (668, 2), (669, 3), (671, 7), (674, 3), (676, 1), (678, 1), (686, 1), (693, 5), (703, 1), (705, 1), (713, 4), (714, 8), (716, 3), (717, 1), (720, 3), (721, 1), (722, 1), (724, 3), (725, 14), (727, 1), (728, 10), (731, 1), (732, 1), (734, 1), (740, 7), (770, 2), (773, 2), (774, 2), (778, 1), (779, 1), (783, 5), (789, 14), (790, 1), (792, 1), (793, 2), (794, 2), (796, 4), (797, 2), (798, 7), (801, 5), (802, 1), (806, 2), (812, 3), (814, 2), (821, 1), (829, 1), (836, 1), (839, 2), (840, 1), (850, 4), (852, 3), (855, 1), (865, 2), (868, 1), (871, 1), (873, 1), (877, 3), (879, 3), (897, 4), (901, 4), (907, 3), (915, 1), (917, 1), (919, 1), (925, 2), (927, 1), (929, 2), (944, 4), (956, 2), (958, 2), (966, 1), (971, 1), (976, 2), (979, 2), (980, 1), (983, 1), (1009, 1), (1019, 1), (1039, 2), (1045, 3), (1046, 2), (1073, 2), (1078, 16), (1097, 1), (1101, 2), (1114, 1), (1132, 2), (1136, 1), (1137, 1), (1160, 3), (1167, 1), (1176, 1), (1196, 4), (1220, 16), (1227, 1), (1229, 1), (1236, 1), (1250, 1), (1252, 1), (1266, 3), (1276, 1), (1286, 1), (1289, 2), (1310, 1), (1314, 2), (1317, 2), (1318, 1), (1319, 4), (1327, 2), (1337, 3), (1343, 1), (1348, 1), (1358, 1), (1365, 2), (1373, 1), (1380, 1), (1392, 1), (1412, 1), (1417, 5), (1436, 1), (1439, 1), (1451, 1), (1457, 2), (1472, 1), (1473, 2), (1479, 1), (1487, 1), (1492, 4), (1499, 1), (1505, 1), (1507, 4), (1508, 1), (1510, 1), (1512, 2), (1513, 1), (1524, 1), (1542, 1), (1553, 1), (1568, 2), (1569, 2), (1576, 1), (1581, 1), (1585, 5), (1591, 1), (1594, 1), (1598, 3), (1601, 2), (1603, 1), (1635, 2), (1643, 2), (1645, 1), (1658, 2), (1660, 1), (1662, 1), (1674, 1), (1700, 1), (1716, 1), (1717, 2), (1718, 1), (1727, 2), (1730, 1), (1743, 1), (1745, 1), (1759, 3), (1762, 2), (1765, 1), (1770, 3), (1793, 1), (1794, 1), (1800, 6), (1808, 1), (1817, 2), (1838, 1), (1847, 1), (1864, 1), (1865, 1), (1868, 1), (1869, 3), (1881, 1), (1889, 2), (1894, 1), (1903, 1), (1907, 1), (1910, 1), (1928, 1), (1940, 2), (1945, 4), (1946, 2), (1969, 1), (1971, 1), (1977, 2), (1981, 1), (2054, 1), (2064, 1), (2069, 1), (2094, 3), (2098, 3), (2103, 3), (2109, 2), (2121, 1), (2134, 1), (2163, 1), (2194, 2), (2201, 1), (2210, 3), (2219, 3), (2226, 2), (2252, 1), (2257, 2), (2266, 1), (2268, 1), (2269, 1), (2278, 2), (2284, 1), (2297, 1), (2309, 1), (2313, 3), (2318, 1), (2322, 2), (2364, 2), (2380, 1), (2383, 1), (2395, 1), (2415, 1), (2417, 1), (2418, 2), (2419, 4), (2427, 1), (2429, 2), (2435, 1), (2455, 1), (2458, 1), (2460, 1), (2485, 1), (2486, 1), (2490, 2), (2495, 2), (2504, 1), (2520, 7), (2522, 1), (2553, 2), (2557, 1), (2558, 1), (2566, 3), (2569, 1), (2609, 6), (2620, 1), (2626, 2), (2646, 2), (2661, 1), (2676, 11), (2695, 2), (2699, 1), (2707, 1), (2709, 1), (2720, 1), (2741, 1), (2742, 1), (2743, 2), (2770, 1), (2774, 1), (2775, 1), (2776, 1), (2779, 1), (2791, 1), (2795, 1), (2802, 2), (2804, 1), (2806, 4), (2833, 2), (2837, 1), (2839, 1), (2841, 1), (2848, 1), (28 ...

# %%
start = time()
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=10, id2word = dictionary, passes=50)
print('used: {:.2f}s'.format(time()-start))
# Out:
# used: 220.90s

# %%
print(ldamodel.print_topics(num_topics=2, num_words=4))
# Out:
# [(2, '0.010*"theory" + 0.005*"one" + 0.005*"education" + 0.005*"memory"'), (0, '0.007*"therapy" + 0.007*"library" + 0.007*"health" + 0.006*"medical"')]

# %%
for i in ldamodel.print_topics(): 
    for j in i: print(j)
# Out:
# 0
# 0.007*"therapy" + 0.007*"library" + 0.007*"health" + 0.006*"medical" + 0.006*"medicine" + 0.006*"woman" + 0.005*"physical" + 0.005*"also" + 0.005*"massage" + 0.005*"disease"
# 1
# 0.008*"law" + 0.006*"religion" + 0.005*"history" + 0.005*"also" + 0.004*"wikipedia" + 0.004*"car" + 0.004*"world" + 0.004*"one" + 0.004*"century" + 0.003*"rome"
# 2
# 0.010*"theory" + 0.005*"one" + 0.005*"education" + 0.005*"memory" + 0.005*"also" + 0.005*"learning" + 0.004*"human" + 0.004*"mind" + 0.004*"study" + 0.004*"logic"
# 3
# 0.007*"cell" + 0.007*"plant" + 0.006*"organism" + 0.006*"system" + 0.006*"energy" + 0.005*"specie" + 0.005*"animal" + 0.004*"life" + 0.004*"one" + 0.004*"form"
# 4
# 0.013*"language" + 0.009*"war" + 0.008*"time" + 0.006*"child" + 0.005*"military" + 0.004*"used" + 0.004*"may" + 0.004*"also" + 0.004*"use" + 0.004*"mining"
# 5
# 0.011*"map" + 0.010*"gender" + 0.008*"political" + 0.006*"social" + 0.005*"state" + 0.004*"system" + 0.004*"also" + 0.004*"woman" + 0.004*"society" + 0.004*"survey"
# 6
# 0.008*"area" + 0.006*"forensic" + 0.006*"leisure" + 0.006*"electric" + 0.005*"space" + 0.005*"time" + 0.005*"navigation" + 0.004*"hobby" + 0.004*"current" + 0.004*"used"
# 7
# 0.006*"world" + 0.005*"year" + 0.005*"population" + 0.005*"china" + 0.004*"country" + 0.004*"also" + 0.004*"greek" + 0.004*"city" + 0.004*"state" + 0.003*"human"
# 8
# 0.006*"human" + 0.006*"science" + 0.006*"social" + 0.005*"study" + 0.005*"technology" + 0.005*"research" + 0.005*"system" + 0.004*"also" + 0.004*"problem" + 0.004*"process"
# 9
# 0.013*"food" + 0.007*"art" + 0.007*"entertainment" + 0.006*"india" + 0.005*"form" + 0.005*"governance" + 0.005*"architecture" + 0.004*"also" + 0.004*"used" + 0.004*"example"

# %%
ldamodel.save('topic.model')

# %%
from gensim.models import LdaModel
loading = LdaModel.load('topic.model')

# %%
print(loading.print_topics(num_topics=2, num_words=4))
# Out:
# [(8, '0.006*"human" + 0.006*"science" + 0.006*"social" + 0.005*"study"'), (7, '0.006*"world" + 0.005*"year" + 0.005*"population" + 0.005*"china"')]

# %%
def pre_new(doc):
    one = cleaning(doc).split()
    two = dictionary.doc2bow(one)
    return two

# %%
pre_new('new article that to be classified by trained model!')
# Out:
# [(261, 1), (495, 1), (740, 1), (4711, 1), (8806, 1)]

# %%
belong = loading[(pre_new('new article that to be classified by trained model!'))]
belong
# Out:
# [(0, 0.2035756),
#  (1, 0.6630084),
#  (2, 0.016680181),
#  (3, 0.01667828),
#  (4, 0.016675446),
#  (5, 0.016675444),
#  (6, 0.01667364),
#  (7, 0.016675701),
#  (8, 0.016681153),
#  (9, 0.016676111)]

# %%
new = pd.DataFrame(belong,columns=['id','prob']).sort_values('prob',ascending=False)
new['topic'] = new['id'].apply(loading.print_topic)
new
# Out:
#    id      prob                                              topic
# 1   1  0.663008  0.008*"law" + 0.006*"religion" + 0.005*"histor...
# 0   0  0.203576  0.007*"therapy" + 0.007*"library" + 0.007*"hea...
# 8   8  0.016681  0.006*"human" + 0.006*"science" + 0.006*"socia...
# 2   2  0.016680  0.010*"theory" + 0.005*"one" + 0.005*"educatio...
# 3   3  0.016678  0.007*"cell" + 0.007*"plant" + 0.006*"organism...
# 9   9  0.016676  0.013*"food" + 0.007*"art" + 0.007*"entertainm...
# 7   7  0.016676  0.006*"world" + 0.005*"year" + 0.005*"populati...
# 4   4  0.016675  0.013*"language" + 0.009*"war" + 0.008*"time" ...
# 5   5  0.016675  0.011*"map" + 0.010*"gender" + 0.008*"politica...
# 6   6  0.016674  0.008*"area" + 0.006*"forensic" + 0.006*"leisu...

# %%
new['topic']
# Out:
# 1    0.008*"law" + 0.006*"religion" + 0.005*"histor...
# 0    0.007*"therapy" + 0.007*"library" + 0.007*"hea...
# 8    0.006*"human" + 0.006*"science" + 0.006*"socia...
# 2    0.010*"theory" + 0.005*"one" + 0.005*"educatio...
# 3    0.007*"cell" + 0.007*"plant" + 0.006*"organism...
# 9    0.013*"food" + 0.007*"art" + 0.007*"entertainm...
# 7    0.006*"world" + 0.005*"year" + 0.005*"populati...
# 4    0.013*"language" + 0.009*"war" + 0.008*"time" ...
# 5    0.011*"map" + 0.010*"gender" + 0.008*"politica...
# 6    0.008*"area" + 0.006*"forensic" + 0.006*"leisu...
# Name: topic, dtype: object

# %%
import gensim
from gensim import corpora

# %%
ran next cell again
# Out:
#   File "<ipython-input-119-7d0cb2b8f431>", line 1
#     ran next cell again
#            ^
# SyntaxError: invalid syntax

# %%
import pyLDAvis.gensim
import gensim
pyLDAvis.enable_notebook()

# %% [markdown]
# ###### conda install -c conda-forge pyldavis finally did it

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %% [markdown]
# Successfully built sklearn
# Installing collected packages: funcy, sklearn, pandas, pyLDAvis
#   Found existing installation: pandas 0.25.1
#     Uninstalling pandas-0.25.1:
#       Successfully uninstalled pandas-0.25.1
# ERROR: Could not install packages due to an EnvironmentError: [WinError 5] Access is denied: 'c:\\users\\owner\\anaconda3\\lib\\site-packages\\~andas\\io\\msgpack\\_packer.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %% [markdown]
# ##### worked anyway?  .. then it worked

# %%
d = gensim.corpora.Dictionary.load('dictionary.dict')
c = gensim.corpora.MmCorpus('corpus.mm')
lda = gensim.models.LdaModel.load('topic.model')

# %% [markdown]
# ###### then, pip install pyLDAvis==2.1.2 or not

# %%
import gensim
from gensim import corpora

# %% [markdown]
# ##### after got to end, came back and ran this again
# The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# --> 232         use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     233         if use_numexpr:
#     234             # error: "None" not callable

# %%
articles = pyLDAvis.gensim.prepare(lda, c, d)
articles
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:459: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   True (duplicates aren't allowed).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-cd069bc4484f> in <module>
# ----> 1 articles = pyLDAvis.gensim.prepare(lda, c, d)
#       2 articles
#
# ~\Anaconda3\lib\site-packages\pyLDAvis\gensim.py in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#     117     """
#     118     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
# --> 119     return vis_prepare(**opts)
#
# ~\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py in prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency, R, lambda_step, mds, n_jobs, plot_opts, sort_topics, start_index)
#     416     def to_json(self):
#     417        return json.dumps(self.to_dict(), cls=NumPyEncoder)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _combine_series_frame(self, other, func, fill_value, axis, level)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_match_index(self, other, func, level)
#    5388             subset = self.columns
#    5389         elif (
# -> 5390             not np.iterable(subset)
#    5391             or isinstance(subset, str)
#    5392             or isinstance(subset, tuple)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     230     op_str = _op_str_mapping[op]
#     231     if op_str is not None:
# --> 232         use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     233         if use_numexpr:
#     234             # error: "None" not callable
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
articles = pyLDAvis.gensim.prepare(optimal_model, corpus, id2word)
articles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-80207a193adb> in <module>
# ----> 1 articles = pyLDAvis.gensim.prepare(optimal_model, corpus, id2word)
#       2 articles
#
# NameError: name 'optimal_model' is not defined

# %%
pyLDAvis.enable_notebook()
articles = pyLDAvis.gensim.prepare(lda, c, d)
articles
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:459: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   True (duplicates aren't allowed).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-722e1628978e> in <module>
#       1 pyLDAvis.enable_notebook()
# ----> 2 articles = pyLDAvis.gensim.prepare(lda, c, d)
#       3 articles
#
# ~\Anaconda3\lib\site-packages\pyLDAvis\gensim.py in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#     117     """
#     118     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
# --> 119     return vis_prepare(**opts)
#
# ~\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py in prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency, R, lambda_step, mds, n_jobs, plot_opts, sort_topics, start_index)
#     416     def to_json(self):
#     417        return json.dumps(self.to_dict(), cls=NumPyEncoder)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _combine_series_frame(self, other, func, fill_value, axis, level)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_match_index(self, other, func, level)
#    5388             subset = self.columns
#    5389         elif (
# -> 5390             not np.iterable(subset)
#    5391             or isinstance(subset, str)
#    5392             or isinstance(subset, tuple)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     230     op_str = _op_str_mapping[op]
#     231     if op_str is not None:
# --> 232         use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     233         if use_numexpr:
#     234             # error: "None" not callable
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
from pyLDAvis import gensim

# %% [markdown]
# ###### worked anyway??

# %%
pyLDAvis.save_html(articles,'vis.html')

# %%
display(HTML(filename = 'vis.html'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-8462c094cf80> in <module>
# ----> 1 display(HTML(filename = 'vis.html'))
#
# NameError: name 'HTML' is not defined

# %%
import codecs
import webbrowser

# %%
webbrowser.open('vis.html')
# Out:
# True

# %% [markdown]
# trying with pyLDAvis.enable_ntebook(local=True) worked for me - some forum
