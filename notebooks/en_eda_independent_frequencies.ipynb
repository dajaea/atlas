# %%
import pandas as pd
import numpy as np
import re
import json
import glob

# %%
folder = (glob.glob('../data/english_topic_full_content/*'))

# %%
article_list = []
for file in folder:
    with open(file, 'r') as f:
        article = json.load(f)
    article_list.append(article)

# %%
articles = pd.DataFrame(article_list).replace(r'^\s*$', np.nan, regex = True)
articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   topic          319 non-null    object
#  1   english_title  243 non-null    object
#  2   english        243 non-null    object
# dtypes: object(3)
# memory usage: 7.6+ KB

# %%
articles = articles.dropna()

# %%
articles = articles.drop_duplicates(subset = ['english_title'])

# %%
articles.head(200)
# Out:
#             topic            english_title  \
# 0    Acceleration             Acceleration
# 1      acceptance               Acceptance
# 4       Aerospace                Aerospace
# 5    Agricultural              Agriculture
# 7        Agronomy                 Agronomy
# ..            ...                      ...
# 271        Speech                   Speech
# 272      Spending  Consumption (economics)
# 273  Spirituality             Spirituality
# 274         Sport                    Sport
# 275    Statistics               Statistics
#
#                                                english
# 0    In mechanics, acceleration is the rate of chan...
# 1    Acceptance in human psychology is a person's a...
# 4    Aerospace is a term used to collectively refer...
# 5    Agriculture is the science, art and practice o...
# 7    Agronomy is the science and technology of prod...
# ..                                                 ...
# ...

# %%
english = articles['english'].to_list()

# %%
#english was clogging mem

# %% [markdown]
#  # HERE

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\feature_extraction\image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

stopwords = set(stopwords.words('english'))
punctuation = set(string.punctuation) 
lemmatize = WordNetLemmatizer()

def cleaning(article):
    one = " ".join([i for i in article.lower().split() if i not in stopwords])
    two = "".join(i for i in one if i not in punctuation)
    three = " ".join(lemmatize.lemmatize(i) for i in two.split())
    four = " ".join(i for i in three.split() if len(i) > 1)
    return four

# %%
clean_eng = [cleaning(x) for x in english]
#print(clean_eng) don't

# %%
clean_eng[0]
# Out:
# 'mechanic acceleration rate change velocity object respect time acceleration vector quantity in magnitude direction orientation object acceleration given orientation net force acting object magnitude object acceleration described newton second law combined effect two cause net balance external force acting onto object magnitude directly proportional net resulting force object mass depending material made magnitude inversely proportional object massthe si unit acceleration metre per second squared m⋅s−2 displaystyle tfrac operatorname operatorname example vehicle start standstill zero velocity inertial frame reference travel straight line increasing speed accelerating direction travel vehicle turn acceleration occurs toward new direction change motion vector acceleration vehicle current direction motion called linear or tangential circular motion acceleration reaction passenger board experience force pushing back seat changing direction effecting acceleration called radial or orthogon
# ...

# %%
english = ' '.join(clean_eng).split()

# %%
import nltk
#from nltk.corpus import webtext
from nltk.probability import FreqDist
 
#nltk.download('webtext')
#wt_words = webtext.words('testing.txt')
data_analysis = nltk.FreqDist(english)
 
#Let's take the specific words only if their frequency is greater than 3.
#filter_words = dict([(m, n) for m, n in data_analysis.items() if len(m) > 5])
 
#for key in sorted(filter_words):
    #print("%s: %s" % (key, filter_words[key]))
 
#data_analysis = nltk.FreqDist(filter_words)
 
#data_analysis.plot(25, cumulative=False)

# %% [markdown]
# data_analysis

# %% [markdown]
# dict(data_analysis)  need this cell after all?

# %% [markdown]
# import string as string

# %%
frequencies_clean = pd.DataFrame.from_dict(dict(data_analysis), orient = 'index').reset_index()

# %%
frequencies_clean.columns = ['word','en_frequency']

# %%
pd.set_option('display.max_rows', 100)

# %%
frequencies_clean.sort_values('en_frequency', ascending = False).head(100)
# Out:
#              word  en_frequency
# 231          also          3199
# 286           one          2550
# 693        system          2530
# 415         human          2464
# 171           may          2354
# 153          used          2166
# 2126        study          2164
# 7            time          2070
# 605          many          1994
# 587         world          1937
# 47        example          1820
# 361        theory          1706
# 726        social          1678
# 573           use          1661
# 387         state          1658
# 890       science          1588
# 163          form          1586
# 610         first          1574
# 1057      century          1554
# 64            new          1548
# 616        people          1487
# 421       process          1453
# 91          often          1428
# 3476     language          1355
# 499          life          1332
# 118          term          1310
# 1081         work          1307
# 971      research          1295
# ...

# %%
frequencies_clean.loc[frequencies_clean.word == 'war']
# Out:
#      word  en_frequency
# 1104  war           679

# %% [markdown]
# frequencies.to_csv('../data/en_independent_frequencies.csv')

# %%
#frequencies_clean = frequencies.iloc[[2,6,9,12,13,14,15,18,20,22,26,27,29,30,35,40,41,43,44,45,46,47,51,52,54,58,59,62,63,64,65,67,68,69,70,72,73,74,78,80,84]]
frequencies_100 = frequencies_clean.iloc[:100]
frequencies_100.head(100)
# Out:
#               word  en_frequency
# 0         mechanic           133
# 1     acceleration           128
# 2             rate           408
# 3           change           987
# 4         velocity            80
# 5           object           597
# 6          respect           105
# 7             time          2070
# 8           vector            44
# 9         quantity           157
# 10              in           283
# 11       magnitude            29
# 12       direction           176
# 13     orientation            62
# 14           given           469
# 15             net            55
# 16           force           560
# 17          acting            71
# 18       described           356
# 19          newton            81
# 20          second           404
# 21             law          1165
# 22        combined           128
# 23          effect           623
# 24             two          1172
# 25           cause           441
# 26         balance            77
# ...

# %%
frequencies_100 = frequencies_clean.sort_values('en_frequency', ascending = False).iloc[:100]
frequencies_100
# Out:
#              word  en_frequency
# 231          also          3199
# 286           one          2550
# 693        system          2530
# 415         human          2464
# 171           may          2354
# 153          used          2166
# 2126        study          2164
# 7            time          2070
# 605          many          1994
# 587         world          1937
# 47        example          1820
# 361        theory          1706
# 726        social          1678
# 573           use          1661
# 387         state          1658
# 890       science          1588
# 163          form          1586
# 610         first          1574
# 1057      century          1554
# 64            new          1548
# 616        people          1487
# 421       process          1453
# 91          often          1428
# 3476     language          1355
# 499          life          1332
# 118          term          1310
# 1081         work          1307
# 971      research          1295
# ...

# %%
import plotly.express as px
fig = px.treemap(frequencies_100, path = ['word'],
                 values = 'en_frequency')
fig.show()
# Out:
# <div>                            <div id="70f3cd7d-eabc-44e4-a2b1-7cf6aeb2e393" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70f3cd7d-eabc-44e4-a2b1-7cf6aeb2e393")) {                    Plotly.newPlot(                        "70f3cd7d-eabc-44e4-a2b1-7cf6aeb2e393",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>en_frequency=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["also", "ancient", "animal", "area", "based", "body", "called", "cell", "century", "change", "city", "common", "computer", "concept", "country", "cultural", "culture", "developed", "development", "different", "early", "economic", "energy", "example", "field", "first", "food", "f
# ...
