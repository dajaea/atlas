# %%
import pandas as pd
import numpy as np
import re
import json
import glob

# %%
folder = (glob.glob('../data/chinese_topic_full_content/*'))

# %%
article_list = []
for file in folder:
    with open(file, 'r') as f:
        article = json.load(f)
    article_list.append(article)

# %%
articles = pd.DataFrame(article_list).replace(r'^\s*$', np.nan, regex = True)
articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   chinese_title  145 non-null    object
#  1   chinese        145 non-null    object
# dtypes: object(2)
# memory usage: 2.4+ KB

# %%
articles = articles.dropna()

# %%
articles = articles.drop_duplicates(subset = ['chinese_title'])

# %%
articles.head(200)
# Out:
#                   chinese_title  \
# 0                    Aerospace
# 1                       Africa
# 2                  Agriculture
# 3                       animal
# 4                    Animation
# ..                          ...
# 140                  Tradition
# 141                    traffic
# 142                         TV
# 143          Various religions
# 144  Water conservancy project
#
#                                                chinese
# 0    Aerospace is the general name of the activitie...
# 1    Afrifa [2] (Latin: Africa), referred to as Afr...
# 2    Agricultural, narrow, specializing in agronomi...
# 3    Animals, or a Metazoan, a group of multi-cell ...
# 4    Animation (English: animation) is a visual res...
# ..                                                 ...
# 140  Traditional refers to the ideas, morality, cus...
# 141  Transportation refers to the exchange of peopl...
# 142  TV (English: Television, referred to as: TV) T...
# ...

# %%
chinese = articles['chinese'].to_list()

# %%
#english was clogging mem

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\feature_extraction\image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

stopwords = set(stopwords.words('english'))
punctuation = set(string.punctuation) 
lemmatize = WordNetLemmatizer()

def cleaning(article):
    one = " ".join([i for i in article.lower().split() if i not in stopwords])
    two = "".join(i for i in one if i not in punctuation)
    three = " ".join(lemmatize.lemmatize(i) for i in two.split())
    four = " ".join(i for i in three.split() if len(i) > 1)
    return four

# %%
clean_zh = [cleaning(x) for x in chinese]
#print(clean_eng) don't

# %%
clean_zh[0]
# Out:
# 'aerospace general name activity occurred development atmosphere space universe aviation aerospace separated detail among them aviation refers navigation activity manned noncarriers atmosphere space refers navigation activity universe space outside atmosphere manned noncarrier however emission recycling process spacecraft must pas atmosphere make necessary contact aerospace spaceship aerospace plane landing horizontal gliding level empty air plane currently developing country best embodiment connection word aerospace also refers science necessary aerospace activity also refers various technology involved development aviation spacecraft yuan huang tie wei jin southern dynasty may first successful flight soviet soviet soviet union alale first first successful entry space aerospace technology highly integrated interdisciplinary modern science technology based mechanic thermodynamics material electronic technology automation technology computer technology jet propulsion technology manufa
# ...

# %%
chinese = ' '.join(clean_zh).split()

# %%
import nltk
#from nltk.corpus import webtext
from nltk.probability import FreqDist
 
#nltk.download('webtext')
#wt_words = webtext.words('testing.txt')
data_analysis = nltk.FreqDist(chinese)
 
#Let's take the specific words only if their frequency is greater than 3.
#filter_words = dict([(m, n) for m, n in data_analysis.items() if len(m) > 5])
 
#for key in sorted(filter_words):
    #print("%s: %s" % (key, filter_words[key]))
 
#data_analysis = nltk.FreqDist(filter_words)
 
#data_analysis.plot(25, cumulative=False)

# %% [markdown]
# data_analysis

# %% [markdown]
# dict(data_analysis)  need this cell after all?

# %% [markdown]
# import string as string

# %%
frequencies_clean = pd.DataFrame.from_dict(dict(data_analysis), orient = 'index').reset_index()

# %%
frequencies_clean.columns = ['word','zh_frequency']

# %%
pd.set_option('display.max_rows', 300)

# %%
frequencies_clean.sort_values('zh_frequency', ascending = False).head(300)
# Out:
#                  word  zh_frequency
# 45               also          1857
# 188            people          1270
# 56            dynasty           917
# 94             system           915
# 288              many           853
# 546          language           813
# 544             china           779
# 1119          chinese           756
# 1044         research           755
# 214             world           748
# 40            country           740
# 1314        different           733
# 127             human           729
# 46            science           728
# 118            social           712
# 558           english           702
# 194              time           684
# 380              year           672
# 492               law           652
# 401               etc           631
# 129           history           622
# 58              first           607
# 2650           theory           573
# 241           ancient           572
# 5         development           561
# ...

# %% [markdown]
# frequencies_clean.loc[frequencies_clean.word == 'war']

# %% [markdown]
# frequencies.to_csv('../data/en_independent_frequencies.csv')

# %%
frequencies_clean = frequencies_clean.iloc[[188,56,94,546,544,1119,1044,214,40,127,46,118,558,492,129,2650,241,5,646,487,489,97,2185,48,116,1065,986,577,403,3479]]
frequencies_300 = frequencies_clean.iloc[:300]
frequencies_300.head(300)
# Out:
#              word  zh_frequency
# 188        people          1270
# 56        dynasty           917
# 94         system           915
# 546      language           813
# 544         china           779
# 1119      chinese           756
# 1044     research           755
# 214         world           748
# 40        country           740
# 127         human           729
# 46        science           728
# 118        social           712
# 558       english           702
# 492           law           652
# 129       history           622
# 2650       theory           573
# 241       ancient           572
# 5     development           561
# 646       century           536
# 487       society           531
# 489     political           518
# 97            art           491
# 2185         work           468
# 48     technology           451
# 116      national           443
# 1065        study           441
# 986       culture           431
# 577        belief           427
# ...

# %%
frequencies_300 = frequencies_clean.sort_values('zh_frequency', ascending = False).iloc[:300]
frequencies_300 = frequencies_300.rename(columns = {'zh_frequency': 'occurance'})
frequencies_300
# Out:
#              word  occurance
# 188        people       1270
# 56        dynasty        917
# 94         system        915
# 546      language        813
# 544         china        779
# 1119      chinese        756
# 1044     research        755
# 214         world        748
# 40        country        740
# 127         human        729
# 46        science        728
# 118        social        712
# 558       english        702
# 492           law        652
# 129       history        622
# 2650       theory        573
# 241       ancient        572
# 5     development        561
# 646       century        536
# 487       society        531
# 489     political        518
# 97            art        491
# 2185         work        468
# 48     technology        451
# 116      national        443
# 1065        study        441
# 986       culture        431
# 577        belief        427
# 403        animal        402
# 3479         song        400

# %%
import plotly.express as px
fig = px.treemap(frequencies_300, path = ['word'],
                 values = 'occurance')
fig.show()
# Out:
# <div>                            <div id="34df51a2-4ef2-4c1c-8e43-a966f94c397f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34df51a2-4ef2-4c1c-8e43-a966f94c397f")) {                    Plotly.newPlot(                        "34df51a2-4ef2-4c1c-8e43-a966f94c397f",                        [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>occurance=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["ancient", "animal", "art", "belief", "century", "china", "chinese", "country", "culture", "development", "dynasty", "english", "history", "human", "language", "law", "national", "people", "political", "research", "science", "social", "society", "song", "study", "system", "technolo
# ...

# %% [markdown]
# fig.write_html(C:\Users\Owner\nssds4\atlas\data\ch_treemap.html)

# %%
fig.write_html(r'C:\Users\Owner\nssds4\atlas\data\ch_treemap.html',
                full_html = False,
                include_plotlyjs = 'cdn')
