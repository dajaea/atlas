# %%
import pandas as pd
import numpy as np
import json
import glob

# %%
folder = (glob.glob('../data/matched_content/*'))

# %%
#all_folder = folder[:]
preview = folder[:]
#print(preview)

# %%
title_columns = ["english_title", "chinese_title"]
data = []
with open(filename, 'r') as f:
    objects = json(f, data)
    for row in objects:
        selected_row = []
        for item in title_columns:
            new_row.append(row[title_columns.index(item)])
            data.append(new_row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-ec9d3864d35d> in <module>
#       2 data = []
#       3 with open(filename, 'r') as f:
# ----> 4     objects = json(f, data)
#       5     for row in objects:
#       6         selected_row = []
#
# TypeError: 'module' object is not callable

# %%
for file in preview:
    for value in open(file, 'r'):
        print(json.loads(value))
# Out:
# {'topic': 'Acceleration', 'english_title': 'Acceleration', 'english': 'In mechanics, acceleration is the rate of change of the velocity of an object with respect to time.\nAccelerations are vector quantities (in that they have magnitude and direction). The orientation of an object\'s acceleration is given by the orientation of the net force acting on that object.  The magnitude of an object\'s acceleration, as described by Newton\'s Second Law, is the combined effect of two causes:\n\nthe net balance of all external forces acting onto that object — magnitude is directly proportional to this net resulting force;\nthat object\'s mass, depending on the materials out of which it is made — magnitude is inversely proportional to the object\'s mass.The SI unit for acceleration is metre per second squared (m⋅s−2, \n  \n    \n      \n        \n          \n            \n              m\n              \n                s\n                \n                  2\n                \n              \n            \n          \n        \n      \n    \n    {\\displaystyle {\\tfrac {\\operatorname {m} }{\\operatorname {s} ^{2}}}}\n  ).\nFor example, when a vehicle starts from a standstill (zero velocity, in an inertial frame of reference) and travels in a straight line at increasing speeds, it is accelerating in the direction of travel.  If the vehicle turns, an acceleration occurs toward the new direction and changes its motion vector.  The acceleration of the vehicle in its current direction of motion is called a linear (or tangential during circular motions) acceleration, the reaction to which the passengers on board experience as a force pushing them back into their seats.  When changing direction, the effecting acceleration is called radial (or orthogonal during circular motions) acceleration, the reaction to which the passengers experience as a centrifugal force.  If the speed of the vehicle decreases, this is an acceleration in the opposite direction and mathematically a negative, sometimes called deceleration, and passengers experience the reaction to deceleration as an inertial force pushing them forward.  Such negative accelerations are often achieved by retrorocket burning in spacecraft.  Both acceleration and deceleration are treated the same, they are both changes in velocity.  Each of these accelerations (tangential, radial, deceleration) is felt by passengers until their relative (differential) velocity are neutralized in reference to the vehicle.  \na=d\\dt v\n\n\n== Definition and properties ==\n\n\n=== Average acceleration ===\n\nAn object\'s average acceleration over a period of time is its change in velocity \n  \n    \n      \n        (\n        Δ\n        \n          v\n        \n        )\n      \n    \n    {\\displaystyle (\\Delta \\mathbf {v} )}\n   divided by the duration of the period \n  \n    \n      \n        (\n        Δ\n        t\n        )\n      \n    \n    {\\displaystyle (\\Delta t)}\n  . Mathematically,\n\n  \n    \n      \n        \n          \n            \n              \n                a\n              \n              ¯\n            \n          \n        \n        =\n        \n          \n            \n              Δ\n              \n                v\n              \n            \n            \n              Δ\n              t\n            \n          \n        \n        .\n      \n    \n    {\\displaystyle {\\bar {\\mathbf {a} }}={\\frac {\\Delta \\mathbf {v} }{\\Delta t}}.}\n  \n\n\n=== Instantaneous acceleration ===\n\nInstantaneous acceleration, meanwhile, is the limit of the average acceleration over an infinitesimal interval of time. In the terms of calculus, instantaneous acceleration is the derivative of the velocity vector with respect to time:\n\n  \n    \n      \n        \n          a\n        \n        =\n        \n          lim\n          \n            \n              Δ\n              t\n            \n            →\n            0\n          \n        \n        \n          \n            \n    ...
# {'topic': 'acceptance', 'english_title': 'Acceptance', 'english': 'Acceptance in human psychology is a person\'s assent to the reality of a situation, recognizing a process or condition (often a negative or uncomfortable situation) without attempting to change it or protest it. The concept is close in meaning to acquiescence, derived from the Latin acquiēscere (to find rest in).\n\n\n== Definition ==\nThe term acceptance is a noun with various different meanings. When the person to whom a proposal is made signifies their assent, it is an "acceptance" of their offer, also called an agreement. For example, if someone gives a gift and another receives it, then they have accepted the gift; therefore, having acceptance. Another definition of acceptance has to do with positive welcome and belonging, favor, and endorsement. For instance, one can like someone and accept them due to their approval of that persons. Another description is that acceptance can be an act of believing or assenting. The definition overlaps with toleration, but acceptance and tolerance are not synonyms.\nAcceptance – "An express act or implication by conduct that manifests assent to the terms of an offer in a manner invited or required by the offer so that a binding contract is formed. The exercise of power conferred by an offer by performance of some act. The act of a person to whom something is offered of tendered by another, whereby the offered demonstrates through an act invited by the offer an intention of retaining the subject of the offer."Eckhart Tolle, a spiritual teacher who is alive today, defines acceptance as a "surrender to the Now" response to anything occurring in any moment of life. There, strength, peace and serenity are available when one stops struggling to resist, or hang on tightly to what is so in any given moment. What do I have right now? Now what am I experiencing? The point is, can one be sad when one is sad, afraid when afraid, silly when silly, happy when happy, judgmental when judgmental, overthinking when overthinking, serene when serene, etc.\nWhat Tolle teaches is to observe what is happening without telling a story about it. For example, Tolle shares in his book Stillness Speaks how easy it is to confuse a story one tells for the facts of a situation. If someone doesn’t return your call one may say “He didn’t have the decency to return my call.” That is the story one tells. On the other hand, the facts of the situation are “He did not call.” The facts don’t tell a story about the person or make a judgment about the situation. The facts are always neutral. When one observes what is happening there is an awareness brought in and then acceptance of the situation becomes an option that is available at any given moment.\nTo simplify, acceptance means allowing; allowing unwanted private experiences (thoughts, feelings and urges) to come and go without struggling with them.\n\n\n== Types ==\nBefore any breakdown to types, it should be recognized that acceptance is treating whatever happens, the actual event which is the outcome of all combined previous events, as overall the best outcome. Acceptance typically contains the concept of approval; the psycho-spiritual use of the term infers a non-judgmental mindset. Acceptance is contrasted with resistance, a term that has strong political and psychoanalytic connotations that do not apply in most contexts. Groups and individuals can show acceptance of various events and conditions in the world; individuals may accept elements of their own thoughts, feelings, and personal histories. For example, psychotherapeutic treatment of a person with depression or anxiety can involve fostering acceptance either for whatever personal circumstances may give rise to those feelings or for the feelings themselves. Psychotherapy can also involve lessening an individual\'s acceptance of various situations.\nNotions of acceptance are prominent in many faiths and meditation practices. For example, Buddhism\'s ...
# {'topic': 'activities', 'english_title': '', 'english': '', 'chinese_title': '', 'chinese': ''}
# {'topic': 'activity', 'english_title': '', 'english': '', 'chinese_title': '', 'chinese': ''}
# {'topic': 'Aerospace', 'english_title': 'Aerospace', 'english': 'Aerospace is a term used to collectively refer to the atmosphere and outer space. Aerospace activity is very diverse, with a multitude of commercial, industrial and military applications. Aerospace engineering consists of aeronautics and astronautics. Aerospace organizations research, design, manufacture, operate, or maintain aircraft and spacecraft. \nThe beginning of space and the ending of the air is considered as 100 km above the ground according to the physical explanation that the air pressure is too low for a lifting body to generate meaningful lift force without exceeding orbital velocity.\n\n\n== Overview ==\nIn most industrial countries, the aerospace industry is a cooperation of the public and private sectors. For example, several states have a civilian space program funded by the government, such as National Aeronautics and Space Administration in the United States, European Space Agency in Europe, the Canadian Space Agency in Canada, Indian Space Research Organisation in India, Japan Aerospace Exploration Agency in Japan, Roscosmos State Corporation for Space Activities in Russia, China National Space Administration in China, SUPARCO in Pakistan, Iranian Space Agency in Iran, and Korea Aerospace Research Institute in South Korea.\nAlong with these public space programs, many companies produce technical tools and components such as spacecraft and satellites. Some known companies involved in space programs include Boeing, Cobham, Airbus, SpaceX, Lockheed Martin, United Technologies, MDA and Northrop Grumman. These companies are also involved in other areas of aerospace, such as the construction of aircraft.\n\n\n== History ==\n\nModern aerospace began with Engineer George Cayley in 1799. Cayley proposed an aircraft with a "fixed wing and a horizontal and vertical tail," defining characteristics of the modern airplane.The 19th century saw the creation of the Aeronautical Society of Great Britain (1866), the American Rocketry Society, and the Institute of Aeronautical Sciences, all of which made aeronautics a more serious scientific discipline. Airmen like Otto Lilienthal, who introduced cambered airfoils in 1891, used gliders to analyze aerodynamic forces. The Wright brothers were interested in Lilienthal\'s work and read several of his publications. They also found inspiration in Octave Chanute, an airman and the author of Progress in Flying Machines (1894). It was the preliminary work of Cayley, Lilienthal, Chanute, and other early aerospace engineers that brought about the first powered sustained flight at Kitty Hawk, North Carolina on December 17, 1903, by the Wright brothers.\nWar and science fiction inspired scientists and engineers like Konstantin Tsiolkovsky and Wernher von Braun to achieve flight beyond the atmosphere. World War II inspired Wernher von Braun to create the V1 and V2 rockets.\nThe launch of Sputnik 1 in October 1957 started the Space Age, and on July 20, 1969 Apollo 11 achieved the first manned moon landing. In April 1981, the Space Shuttle Columbia launched, the start of regular manned access to orbital space. A sustained human presence in orbital space started with "Mir" in 1986 and is continued by the "International Space Station". Space commercialization and space tourism are more recent features of aerospace.\n\n\n== Manufacturing ==\n\nAerospace manufacturing is a high-technology industry that produces "aircraft, guided missiles, space vehicles, aircraft engines, propulsion units, and related parts". Most of the industry is geared toward governmental work.  For each original equipment manufacturer (OEM), the US government has assigned a Commercial and Government Entity (CAGE) code. These codes help to identify each manufacturer, repair facilities, and other critical aftermarket vendors in the aerospace industry.\nIn the United States, the Department of Defense and the National Aeronautics and Space Administration (NASA) are ...
# {'topic': 'Agricultural', 'english_title': 'Agriculture', 'english': 'Agriculture is the science, art and practice of cultivating plants and livestock. Agriculture was the key development in the rise of sedentary human civilization, whereby farming of domesticated species created food surpluses that enabled people to live in cities. The history of agriculture began thousands of years ago. After gathering wild grains beginning at least 105,000 years ago, nascent farmers began to plant them around 11,500 years ago. Pigs, sheep, and cattle were domesticated over 10,000 years ago. Plants were independently cultivated in at least 11 regions of the world. Industrial agriculture based on large-scale monoculture in the twentieth century came to dominate agricultural output, though about 2 billion people still depended on subsistence agriculture.\nModern agronomy, plant breeding, agrochemicals such as pesticides and fertilizers, and technological developments have sharply increased crop yields, while causing widespread ecological and environmental damage. Selective breeding and modern practices in animal husbandry have similarly increased the output of meat, but have raised concerns about animal welfare and environmental damage. Environmental issues include contributions to global warming, depletion of aquifers, deforestation, antibiotic resistance, and growth hormones in industrial meat production. Agriculture is also very sensitive to environmental degradation, such as biodiversity loss, desertification, soil degradation and global warming, which cause decrease in crop yield. Genetically modified organisms are widely used, although some are banned in certain countries.\nThe major agricultural products can be broadly grouped into foods, fibers, fuels and raw materials (such as rubber). Food classes include cereals (grains), vegetables, fruits, oils, meat, milk, fungi and eggs. Over one-third of the world\'s workers are employed in agriculture, second only to the service sector, although in recent decades, the global trend of a decreasing number of agricultural workers continues, especially in developing countries where smallholding is being overtaken by industrial agriculture and mechanization. Creating global sustainable food systems which provides food security with sustainable agriculture practices is an international policy priority articulated in Sustainable Development Goal 2: "Zero hunger", adopted by the United Nations in 2015.\n\n\n== Etymology and scope ==\n\nThe word agriculture is a late Middle English adaptation of Latin agricultūra, from ager, "field", and cultūra, "cultivation" or "growing". While agriculture usually refers to human activities, certain species of ant, termite and beetle have been cultivating crops for up to 60 million years. Agriculture is defined with varying scopes, in its broadest sense using natural resources to "produce commodities which maintain life, including food, fiber, forest products, horticultural crops, and their related services". Thus defined, it includes arable farming, horticulture, animal husbandry and forestry, but horticulture and forestry are in practice often excluded.\n\n\n== History ==\n\n\n=== Origins ===\n\nThe development of agriculture enabled the human population to grow many times larger than could be sustained by hunting and gathering. Agriculture began independently in different parts of the globe, and included a diverse range of taxa, in at least 11 separate centres of origin. Wild grains were collected and eaten from at least 105,000 years ago. From around 11,500 years ago, the eight Neolithic founder crops, emmer and einkorn wheat, hulled barley, peas, lentils, bitter vetch, chick peas and flax were cultivated in the Levant. Rice was domesticated in China between 11,500 and 6,200 BC with the earliest known cultivation from 5,700 BC, followed by mung, soy and azuki beans. Sheep were domesticated in Mesopotamia between 13,000 and 11,000 years ago. Cattle were domesticat ...
# {'topic': 'Agriculture', 'english_title': 'Agriculture', 'english': 'Agriculture is the science, art and practice of cultivating plants and livestock. Agriculture was the key development in the rise of sedentary human civilization, whereby farming of domesticated species created food surpluses that enabled people to live in cities. The history of agriculture began thousands of years ago. After gathering wild grains beginning at least 105,000 years ago, nascent farmers began to plant them around 11,500 years ago. Pigs, sheep, and cattle were domesticated over 10,000 years ago. Plants were independently cultivated in at least 11 regions of the world. Industrial agriculture based on large-scale monoculture in the twentieth century came to dominate agricultural output, though about 2 billion people still depended on subsistence agriculture.\nModern agronomy, plant breeding, agrochemicals such as pesticides and fertilizers, and technological developments have sharply increased crop yields, while causing widespread ecological and environmental damage. Selective breeding and modern practices in animal husbandry have similarly increased the output of meat, but have raised concerns about animal welfare and environmental damage. Environmental issues include contributions to global warming, depletion of aquifers, deforestation, antibiotic resistance, and growth hormones in industrial meat production. Agriculture is also very sensitive to environmental degradation, such as biodiversity loss, desertification, soil degradation and global warming, which cause decrease in crop yield. Genetically modified organisms are widely used, although some are banned in certain countries.\nThe major agricultural products can be broadly grouped into foods, fibers, fuels and raw materials (such as rubber). Food classes include cereals (grains), vegetables, fruits, oils, meat, milk, fungi and eggs. Over one-third of the world\'s workers are employed in agriculture, second only to the service sector, although in recent decades, the global trend of a decreasing number of agricultural workers continues, especially in developing countries where smallholding is being overtaken by industrial agriculture and mechanization. Creating global sustainable food systems which provides food security with sustainable agriculture practices is an international policy priority articulated in Sustainable Development Goal 2: "Zero hunger", adopted by the United Nations in 2015.\n\n\n== Etymology and scope ==\n\nThe word agriculture is a late Middle English adaptation of Latin agricultūra, from ager, "field", and cultūra, "cultivation" or "growing". While agriculture usually refers to human activities, certain species of ant, termite and beetle have been cultivating crops for up to 60 million years. Agriculture is defined with varying scopes, in its broadest sense using natural resources to "produce commodities which maintain life, including food, fiber, forest products, horticultural crops, and their related services". Thus defined, it includes arable farming, horticulture, animal husbandry and forestry, but horticulture and forestry are in practice often excluded.\n\n\n== History ==\n\n\n=== Origins ===\n\nThe development of agriculture enabled the human population to grow many times larger than could be sustained by hunting and gathering. Agriculture began independently in different parts of the globe, and included a diverse range of taxa, in at least 11 separate centres of origin. Wild grains were collected and eaten from at least 105,000 years ago. From around 11,500 years ago, the eight Neolithic founder crops, emmer and einkorn wheat, hulled barley, peas, lentils, bitter vetch, chick peas and flax were cultivated in the Levant. Rice was domesticated in China between 11,500 and 6,200 BC with the earliest known cultivation from 5,700 BC, followed by mung, soy and azuki beans. Sheep were domesticated in Mesopotamia between 13,000 and 11,000 years ago. Cattle were domesticate ...
# {'topic': 'Agronomy', 'english_title': 'Agronomy', 'english': 'Agronomy is the science and technology of producing and using plants in agriculture for food, fuel, fiber, recreation, and land restoration. Agronomy has come to encompass work in the areas of plant genetics, plant physiology, meteorology, and soil science. It is the application of a combination of sciences like biology, chemistry, economics, ecology, earth science, and genetics. Professionals in the field of agronomy are called agronomists. \n\n\n== Plant breeding ==\n\nThis area of agronomy involves selective breeding of plants to produce the best crops under various conditions. Plant breeding has increased crop yields and has improved the nutritional value of numerous crops, including corn, soybeans, and wheat. It has also led to the development of new types of plants. For example, a hybrid grain called triticale was produced by crossbreeding rye and wheat. Triticale contains more usable protein than does either rye or wheat. Agronomy has also been instrumental in fruit and vegetable production research. Additionally, in turfgrass science, the use of plant breeding has led to reduction in need for fertilizer and water inputs (requirements) as well as turf-types which show increased resistance to diseases.\n\n\n== Biotechnology ==\n\nAgronomists use biotechnology to extend and expedite the development of desired characteristic.  Biotechnology is often a lab activity requiring field testing of the new crop varieties that are developed.\nIn addition to increasing crop yields agronomic biotechnology is increasingly being applied for novel uses other than food. For example, oilseed is at present used mainly for margarine and other food oils, but it can be modified to produce fatty acids for detergents, substitute fuels and petrochemicals.\n\n\n== Soil science ==\n\nAgronomists study sustainable ways to make soils more productive and profitable throughout the world. They classify soils and analyze them to determine whether they contain nutrients vital to plant growth. Common macronutrients analyzed include compounds of nitrogen, phosphorus, potassium, calcium, magnesium, and sulfur. Soil is also assessed for several micronutrients, like zinc and boron. The percentage of organic matter, Soil pH, and nutrient holding capacity (cation exchange capacity) are tested in a regional laboratory. Agronomists will interpret these lab reports and make recommendations to balance soil nutrients for optimal plant growth.\n\n\n=== Soil conservation ===\nIn addition, agronomists develop methods to preserve the soil and to decrease the effects of erosion by wind and water. For example, a technique called contour plowing may be used to prevent soil erosion and conserve rainfall. Researchers in agronomy also seek ways to use the soil more effectively in solving other problems. Such problems include the disposal of human and animal manure, water pollution, and pesticide build-up in the soil. As well as looking after the soil for future generations to come, such as the burning of paddocks after crop production. Pasture management techniques include no-till farming, planting of soil-binding grasses along contours on steep slopes, and using contour drains of depths up to 1 metre.\n\n\n== Agroecology ==\nAgroecology is the management of agricultural systems with an emphasis on ecological and environmental perspectives. This area is closely associated with work in the areas of sustainable agriculture, organic farming, and alternative food systems and the development of alternative cropping systems.\n\n\n== Theoretical modeling ==\nTheoretical production ecology tries to quantitatively study the growth of crops. The plant is treated as a kind of biological factory, which processes light, carbon dioxide, water, and nutrients into harvestable products. The main parameters considered are temperature, sunlight, standing crop biomass, plant production distribution, and nutrient and water supply.\n\n ...
# {'topic': 'alternative', 'english_title': '', 'english': '', 'chinese_title': 'Alternative rock ', 'chinese': 'Alternative rock (English: Alternative Rock), also known as alternative music or replace rock or alternative music, referred to as alternative or alternative. It is a kind of music category in rock music, from the 1980s in the 1990s, and began to popularize in the 1990s to the 2000s. The word Alternative means that it is different from mainstream music, and mainstream music is disaccent, alternative rock is different from mainstream rock music, mainly reflected in the unique guitar manifestations, subversive lyrics and a gentle care attitude. Alternative rock original range is a relatively wide range of different sound expressions, different social backgrounds, cultural backgrounds. In the late 1970s, all underground rocks, punk rocks (including punk, new wave, and then punks) were identified as alternative rock.\nIn the late 1980s, with the magazine report, the discretion of the university campus broadcast and some oral publicity emphasized the diversity and difference of alternative rock, and helped define different musical styles (such as Gothic rock, noise, independence Rock, independent popular, oil rock, industrial rock, hip hop roll, and alternative hip hop). Most of the sub-classifications have their own audience, some of which have a representative band like Hüsker Dü and R.E.m. even sign a record company. However, the achievements of most commercial alternative rock bands are limited at the time of rock music and pop music relative to other categories. Some works are still being classified as a personal work, only a small number of broadcasts, and the TV media will play their songs. In the 1990s, with the breakthroughs brought about by the ultra-vendor, the popularity of oil and rock rock, the alternative rock gradually received by the public, turned into a mainstream music, and many alternative rock bands have also achieved business. Successful.\nIn the late 1990s, the impact of the retreat of oil and rock and British rock boom, alternative rocks were no longer so special and outstanding in mainstream music.\n\n\n== The origin of the term ==\nAlternative rock definitions in English English, especially referring to "Indie Rock" (independent rock) (although this type of definition limit has become blurred under electronic music and hip hop music), it is used to it in American English. "Alternative Rock". Sometimes the underground music is a representation of the alternative rock, but underground music is usually referred to as music performances performed by unusual awareness or orchestra, and "Indie" (independent) is often used in the UK. On behalf of the alternative rock, the word in Taiwan was translated into "hard", with "hard-style" and "underground" meaning (see Taiwan\'s hard music festival, a music event mainly based on underground orchestras, alternative rock ). Or ALTERNATIVE is a type in rock and roll, which appeared in 1980 and began wide popular in the 1990s. "Alternative" This single word "Optional" is also used in the 1980s, also used to refer to the Bumark Rolling Style Orchestra of the Independent Record Brand, and they and the mainstream music type at the time is different. As a specific music type, the alternative rock has gathered many separate music sub-types, such as oil stains, independent rock, English rock, Gothic rock rock.\n\n\n== Reference material ==\n\n\n== External link == '}
# {'topic': 'analysis', 'english_title': 'Analysis', 'english': 'Analysis is the process of breaking a complex topic or substance into smaller parts in order to gain a better understanding of it. The technique has been applied in the study of mathematics and logic since before Aristotle (384–322 B.C.), though analysis as a formal concept is a relatively recent development.The word comes from the Ancient Greek ἀνάλυσις (analysis, "a breaking-up" or "an untying;" from ana- "up, throughout" and lysis "a loosening"). From it also comes the word\'s plural, analyses.\nAs a formal concept, the method has variously been ascribed to Alhazen, René Descartes (Discourse on the Method), and Galileo Galilei. It has also been ascribed to Isaac Newton, in the form of a practical method of physical discovery (which he did not name).\n\n\n== Applications ==\n\n\n=== Science ===\n\nThe field of chemistry uses analysis in at least three ways: to identify the components of a particular chemical compound (qualitative analysis), to identify the proportions of components in a mixture (quantitative analysis), and to break down chemical processes and examine chemical reactions between elements of matter. For an example of its use, analysis of the concentration of elements is important in managing a nuclear reactor, so nuclear scientists will analyse neutron activation to develop discrete measurements within vast samples. A matrix can have a considerable effect on the way a chemical analysis is conducted and the quality of its results. Analysis can be done manually or with a device. Chemical analysis is an important element of national security among the major world powers with materials\nTypes of Analysis:\nA) Qualitative Analysis: It is concerned with which components are in a given sample or compound.\nExample: Precipitation reaction\nB) Quantitative Analysis: It is to determine the quantity of individual component present in a given sample or compound.\nExample:To find concentration by uv-spectrophotometer.\n\n\n==== Isotopes ====\n\nChemists can use isotope analysis to assist analysts with issues in anthropology, archeology, food chemistry, forensics, geology, and a host of other questions of physical science. Analysts can discern the origins of natural and man-made isotopes in the study of environmental radioactivity.\n\n\n=== Business ===\nFinancial statement analysis – the analysis of the accounts and the economic prospects of a firm\nFundamental analysis – a stock valuation method that uses financial analysis\nGap analysis – involves the comparison of actual performance with potential or desired performance of an organization\nBusiness analysis – involves identifying the needs and determining the solutions to business problems\nPrice analysis – involves the breakdown of a price to a unit figure\nMarket analysis – consists of suppliers and customers, and price is determined by the interaction of supply and demand\nTechnical analysis – the study of price action in securities markets in order to forecast future prices\nOpportunity analysis – consists of customers trends within the industry, customer demand and experience determine purchasing behavior\n\n\n=== Computer science ===\nRequirements analysis – encompasses those tasks that go into determining the needs or conditions to meet for a new or altered product, taking account of the possibly conflicting requirements of the various stakeholders, such as beneficiaries or users.\nCompetitive analysis (online algorithm) – shows how online algorithms perform and demonstrates the power of randomization in algorithms\nLexical analysis – the process of processing an input sequence of characters and producing as output a sequence of symbols\nObject-oriented analysis and design – à la Booch\nProgram analysis (computer science) – the process of automatically analysing the behavior of computer programs\nSemantic analysis (computer science) – a pass by a compiler that adds semantical information to the parse t ...

# %%
preview_list = []
for file in preview:
    with open(file, 'r') as f:
        article = json.load(f)
    preview_list.append(article)

# %%
preview_frame = pd.DataFrame(preview_list).replace(r'^\s*$', np.nan, regex=True)
#.replace('', None)
#preview_frame.loc[0, 'chinese']
preview_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 5 columns):
# topic            319 non-null object
# english_title    243 non-null object
# english          243 non-null object
# chinese_title    42 non-null object
# chinese          42 non-null object
# dtypes: object(5)
# memory usage: 12.6+ KB

# %%
preview_frame.dropna()
# Out:
#             topic english_title  \
# 15    Archaeology   Archaeology
# 16   Architecture  Architecture
# 17           area          Area
# 18           arts      The arts
# 34     Biophysics    Biophysics
# 37         Botany        Botany
# 39           Cars           Car
# 49           City          City
# 59       computer      Computer
# 62   Construction  Construction
# 71        density       Density
# 72      Dentistry     Dentistry
# 73         Design        Design
# 83          Earth         Earth
# 88      Education     Education
# 93         Energy        Energy
# 104   Exploration   Exploration
# 109          Food          Food
# 126        Greece        Greece
# 142    Immunology    Immunology
# 144         India         India
# 151    Innovation    Innovation
# 158      Language      Language
# 187        Mining        Mining
# 195        Nature        Nature
# 197  neuroscience  Neuroscience
# 207  Parasitology  Parasitology
# 209     Pathology     Pathology
# 216      Pharmacy      Pharmacy
# 220    Physiology    Physiology
# 243    Psychology    Psychology
# 257       Science       Science
# 283       Systems        System
# 286        Techno        Techno
# 299      Timeline      Timeline
# 307          Tree          Tree
# 316     Wikipedia     Wikipedia
#
#                                                english  \
# 15   Archaeology or archeology is the study of huma...
# 16   Architecture (Latin architectura, from the Gre...
# 17   Area is the quantity that expresses the extent...
# 18   The arts are a very wide range of human practi...
# 34   Biophysics is an interdisciplinary science tha...
# 37   Botany, also called plant science(s), plant bi...
# 39   A car (or automobile) is a wheeled motor vehic...
# 49   A city is a large human settlement. It can be ...
# 59   A computer is a machine that can be programmed...
# 62   Construction is a general term meaning the art...
# 71   The density (more precisely, the volumetric ma...
# 72   Dentistry, also known as dental medicine and o...
# 73   A design is a plan or specification for the co...
# 83   Earth is the third planet from the Sun and the...
# 88   Education is the process of facilitating learn...
# 93   In physics, energy is the quantitative propert...
# 104  Exploration is the act of searching for the pu...
# 109  Food is any substance consumed to provide nutr...
# 126  Greece (Greek: Ελλάδα, Elláda, [eˈlaða]), offi...
# 142  Immunology is a branch of biology that covers ...
# 144  India (Hindi: Bhārat), officially the Republic...
# 151  Innovation is the practical implementation of ...
# 158  A language is a structured system of communica...
# 187  Mining is the extraction of valuable minerals ...
# 195  Nature, in the broadest sense, is the natural,...
# 197  Neuroscience (or neurobiology) is the scientif...
# 207  Parasitology is the study of parasites, their ...
# 209  Pathology is the study of the causes and effec...
# 216  Pharmacy is the clinical health science that l...
# 220  Physiology (; from Ancient Greek  φύσις (physi...
# 243  Psychology is the science of mind and behavior...
# 257  Science (from the Latin word scientia, meaning...
# 283  A system is a group of interacting or interrel...
# 286  Techno is a genre of electronic dance music (E...
# 299  A timeline is a display of a list of events in...
# 307  In botany, a tree is a perennial plant with an...
# 316  Wikipedia ( (listen) wik-ih-PEE-dee-ə or  (lis...
#
#               chinese_title                                            chinese
# 15              archeology   Archaeological (English: Archaeology or Archeo...
# 16                building   Building, usually referring to all or part of ...
# 17                    Area   Area is a group established in 1972 formerly g...
# 18             Art species   Art is a manifestation of performance, which w...
# 34              Biophysics   Biophysics (English: Biophysics) is a cross-di...
# 37                  botany   Botany is a comprehensive science that study p...
# 39        Car mobilization   "Racing Mobilization" (English: CARS), made by...
# 49                    city   Urban, urban, city, city or capital refers to ...
# 59   electronic calculator   The electronic computer (also known as compute...
# 62   Building Construction   In architecture and civil engineering, constru...
# 71                 density   The density refers to the mass of the unit vol...
# 72         Dental medicine   Dentistry (French: DentiSterie; English: Denti...
# 73                  design   The so-called design, that is, "ideas and plan...
# 83                   Earth   Earth is the third planet in the solar system,...
# 88               education   Education, usually there are broad and narrow ...
# 93                  Energy   Energy is Taiwan to dance famous men's group, ...
# 104              Adventure   Adventures refer to search activities for disc...
# 109                   food   The food is a nutrient for biological, usually...
# 126                 Greece   Greek Republic (Greek: λληνική Δη μκκρατία, Gr...
# 142             Immunology   Immunology (English: Immunology) is a major bi...
# 144                  India   Republic of India (Hindi: भारत गणराज्य, Bhārat...
# 151             Innovation   "Innovation" is the third personal album of Sn...
# 158               Language   Language is a class of composite AC systems, m...
# 187       Mining (Austria)   Mining (German: Mining) is an urban town in Bo...
# 195       Nature (journal)   "Nature" (English: Nature) is one of the earli...
# 197           Neuroscience   Neuroscience (English: neuroscience), also kno...
# 207              Parasitic   Parasitic is a science that studies the relati...
# 209              Pathology   Pathology (English: Pathology) is a branch dis...
# 216               Pharmacy   Pharmacy (English: Pharmacy), is based on vari...
# 220             Physiology   Physiology (English: Physiology / ˌfɪziɒlədʒi ...
# 243             psychology   Psychology (English: Psychology) is a scientif...
# 257      Science (journal)   "Science" (English: Science) is an academic jo...
# 283                Systems   Systems (system) is an IT industry's professio...
# 286                 Techno   Techno, translated "High Tech Dance", "Tienkno...
# 299               Timeline   The timeline, also known as the timeline, and ...
# 307                   tree   The tree is plants with wooden trunk and branc...
# 316              Wikipedia   Wikipedia (English: wikipedia, / ˌW ɪɪpiːpiːː ...

# %%
#def print_title():
    for file in preview:
        open(file, 'r'):
            print(json.loads(file['english_title'])
# Out:
#   File "<ipython-input-47-90aa5d90a88c>", line 3
#     open(file, 'r'):
#                     ^
# SyntaxError: invalid syntax

# %%
for file in preview:
     = json.loads(file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-50-516acad26de5> in <module>
#       1 for file in preview:
# ----> 2     data_dict = json.loads(file)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# data_list = []
# for file in os.listdir(base_dir):
#
#     #If file is a json, construct it's full path and open it, append all json data to list
#     if 'json' in file:
#         json_path = os.path.join(base_dir, file)
#         json_data = pd.read_json(json_path, lines=True)
#         data_list.append(json_data)
#
# print(data_list)

# %%
with open(f'../data/content_{topic}.json', 'w') as fi:
        json.dump({
          
            'topic':topic,
            'english_title':en_title,
            'english':en_topic_content,
            'chinese_title':zh_title,
            'chinese':zh_topic_content
                        
        }, fi)

for topic in en_all_topics:
    
    try:
        article = wiki.page(topic, auto_suggest = False)
        en_topic_content = (article.content)
        en_title = article.title
    except:
        en_topic_content = ''
        en_title = ''
    
    wiki.set_lang("zh")
    try:
        article = wiki.page(topic, auto_suggest = False)
#       zh_topic_content = translator.translate(article.content, lang_tgt = 'en')
        zh_title = translator.translate(article.title, lang_tgt = 'en')
        
        remain_text = article.content
        zh_topic_content = ''
        
        while len(remain_text) > 0:
            zh_topic_content += translator.translate(remain_text[0:4999])
            remain_text = remain_text[4999:]
    except:
        zh_topic_content = ''
        zh_title = ''

# %%
use ijson to iteratively process the JSON file

# %%
article_list = []
for file in folder:
    with open(file, 'r') as f:
        article = json.load(f)
    article_list.append(article)

# %%
articles = pd.DataFrame(article_list).replace(r'^\s*$', np.nan, regex = True)
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 5 columns):
# topic            319 non-null object
# english_title    243 non-null object
# english          243 non-null object
# chinese_title    42 non-null object
# chinese          42 non-null object
# dtypes: object(5)
# memory usage: 12.6+ KB

# %%
articles = articles.dropna()

# %%
articles.head(200)
# Out:
#              topic  english_title  \
# 15     Archaeology    Archaeology
# 16    Architecture   Architecture
# 17            area           Area
# 18            arts       The arts
# 29    Biochemistry   Biochemistry
# 34      Biophysics     Biophysics
# 37          Botany         Botany
# 39            Cars            Car
# 49            City           City
# 59        computer       Computer
# 61   Consciousness  Consciousness
# 62    Construction   Construction
# 71         density        Density
# 72       Dentistry      Dentistry
# 73          Design         Design
# 83           Earth          Earth
# 88       Education      Education
# 90           Egypt          Egypt
# 93          Energy         Energy
# 104    Exploration    Exploration
# 106       Feminist       Feminism
# 109           Food           Food
# 119       genetics       Genetics
# 126         Greece         Greece
# 142     Immunology     Immunology
# 144          India          India
# 151     Innovation     Innovation
# 154       Internet       Internet
# 158       Language       Language
# 187         Mining         Mining
# 195         Nature         Nature
# 197   neuroscience   Neuroscience
# 207   Parasitology   Parasitology
# 209      Pathology      Pathology
# 216       Pharmacy       Pharmacy
# 220     Physiology     Physiology
# 243     Psychology     Psychology
# 256           Rome           Rome
# 257        Science        Science
# 259           self           Self
# 267       software       Software
# 283        Systems         System
# 286         Techno         Techno
# 299       Timeline       Timeline
# 307           Tree           Tree
# 316      Wikipedia      Wikipedia
#
#                                                english  \
# 15   [Archaeology, archeology, study, human, activi...
# 16   [Architecture, Latin, architectura, Greek, ἀρχ...
# 17   [Area, quantity, expresses, extent, two, dimen...
# 18   [The, arts, wide, range, human, practices, cre...
# 29   [Biochemistry, biological, chemistry, study, c...
# 34   [Biophysics, interdisciplinary, science, appli...
# 37   [Botany, also, called, plant, science, plant, ...
# 39   [A, car, automobile, wheeled, motor, vehicle, ...
# 49   [A, city, large, human, settlement, It, define...
# 59   [A, computer, machine, programmed, carry, sequ...
# 61   [Consciousness, simplest, sentience, awareness...
# 62   [Construction, general, term, meaning, art, sc...
# 71   [The, density, precisely, volumetric, mass, de...
# 72   [Dentistry, also, known, dental, medicine, ora...
# 73   [A, design, plan, specification, construction,...
# 83   [Earth, third, planet, Sun, astronomical, obje...
# 88   [Education, process, facilitating, learning, a...
# 90   [Egypt, listen, EE, jipt, Arabic, م, صر, roman...
# 93   [In, physics, energy, quantitative, property, ...
# 104  [Exploration, act, searching, purpose, discove...
# 106  [Feminism, range, social, movements, political...
# 109  [Food, substance, consumed, provide, nutrition...
# 119  [Genetics, branch, biology, concerned, study, ...
# 126  [Greece, Greek, Ελλάδα, Elláda, eˈlaða, offici...
# 142  [Immunology, branch, biology, covers, study, i...
# 144  [India, Hindi, Bhārat, officially, Republic, I...
# 151  [Innovation, practical, implementation, ideas,...
# 154  [The, Internet, internet, global, system, inte...
# 158  [A, language, structured, system, communicatio...
# 187  [Mining, extraction, valuable, minerals, geolo...
# 195  [Nature, broadest, sense, natural, physical, m...
# 197  [Neuroscience, neurobiology, scientific, study...
# 207  [Parasitology, study, parasites, hosts, relati...
# 209  [Pathology, study, causes, effects, disease, i...
# 216  [Pharmacy, clinical, health, science, links, m...
# 220  [Physiology, Ancient, Greek, φύσις, physis, na...
# 243  [Psychology, science, mind, behavior, Psycholo...
# 256  [Rome, Italian, Latin, Roma, ˈroːma, listen, c...
# 257  [Science, Latin, word, scientia, meaning, know...
# 259  [The, self, individual, person, object, reflec...
# 267  [Software, collection, instructions, data, tel...
# 283  [A, system, group, interacting, interrelated, ...
# 286  [Techno, genre, electronic, dance, music, EDM,...
# 299  [A, timeline, display, list, events, chronolog...
# 307  [In, botany, tree, perennial, plant, elongated...
# 316  [Wikipedia, listen, wik, ih, PEE, dee, ə, list...
#
#               chinese_title  \
# 15              archeology
# 16                building
# 17                    Area
# 18             Art species
# 29            Biochemistry
# 34              Biophysics
# 37                  botany
# 39        Car mobilization
# 49                    city
# 59   electronic calculator
# 61               awareness
# 62   Building Construction
# 71                 density
# 72         Dental medicine
# 73                  design
# 83                   Earth
# 88               education
# 90                   Egypt
# 93                  Energy
# 104              Adventure
# 106              Femaleism
# 109                   food
# 119               Genetics
# 126                 Greece
# 142             Immunology
# 144                  India
# 151             Innovation
# 154           the Internet
# 158               Language
# 187       Mining (Austria)
# 195       Nature (journal)
# 197           Neuroscience
# 207              Parasitic
# 209              Pathology
# 216               Pharmacy
# 220             Physiology
# 243             psychology
# 256                   Rome
# 257      Science (journal)
# 259                   Self
# 267               software
# 283                Systems
# 286                 Techno
# 299               Timeline
# 307                   tree
# 316              Wikipedia
#
#                                                chinese  en_char_count  \
# 15   [Archaeological, English, Archaeology, Archeol...         4865.0
# 16   [Building, usually, referring, part, behavior,...         2761.0
# 17   [Area, group, established, 1972, formerly, gua...         2796.0
# 18   [Art, manifestation, performance, affected, cu...         2156.0
# 29   [Biochemistry, English, Biochemistry, also, ma...         2889.0
# 34   [Biophysics, English, Biophysics, cross, disci...          719.0
# 37   [Botany, comprehensive, science, study, plant,...         5079.0
# 39   [Racing, Mobilization, English, CARS, made, Pi...         3650.0
# 49   [Urban, urban, city, city, capital, refers, re...         6697.0
# 59   [The, electronic, computer, also, known, compu...         5752.0
# 61   [Consciousness, cognitive, ability, people, se...         6677.0
# 62   [In, architecture, civil, engineering, constru...         2615.0
# 71   [The, density, refers, mass, unit, volume, sub...         1581.0
# 72   [Dentistry, French, DentiSterie, English, Dent...         2197.0
# 73   [The, called, design, ideas, plans, ideas, pur...         1371.0
# 83   [Earth, third, planet, solar, system, sun, 149...         5524.0
# 88   [Education, usually, broad, narrow, concepts, ...         5194.0
# 90   [Arab, Egypt, Arabic, ججههرةة, صصصالعربةة, pro...        10041.0
# 93   [Energy, Taiwan, dance, famous, men, group, Ju...         3852.0
# 104  [Adventures, refer, search, activities, discov...         1789.0
# 106  [Feminism, English, feminism, also, known, wom...         7141.0
# 109  [The, food, nutrient, biological, usually, pla...         6078.0
# 119  [Genetics, scientific, variant, graduate, obje...         3895.0
# 126  [Greek, Republic, Greek, λληνική, Δη, μκκρατία...        12928.0
# 142  [Immunology, English, Immunology, major, big, ...         1473.0
# 144  [Republic, India, Hindi, भ, रत, गणर, ज, य, Bhā...         7903.0
# 151  [Innovation, third, personal, album, Snow, lau...         3714.0
# 154  [The, Internet, English, Internet, refers, hug...         7019.0
# 158  [Language, class, composite, AC, systems, main...         7412.0
# 187  [Mining, German, Mining, urban, town, Bora, Co...         5484.0
# 195  [Nature, English, Nature, one, earliest, scien...         3697.0
# 197  [Neuroscience, English, neuroscience, also, kn...         2284.0
# 207  [Parasitic, science, studies, relationship, pa...          675.0
# 209  [Pathology, English, Pathology, branch, discip...         2784.0
# 216  [Pharmacy, English, Pharmacy, based, various, ...         3812.0
# 220  [Physiology, English, Physiology, ˌfɪziɒlədʒi,...         1669.0
# 243  [Psychology, English, Psychology, scientific, ...         8955.0
# 256  [Rome, Righteree, Roma, Roːma, capital, capita...         9834.0
# 257  [Science, English, Science, academic, journal,...         5848.0
# 259  [The, Self, language, prototype, oriented, pro...         1346.0
# 267  [Software, English, Software, series, computer...         1992.0
# 283  [Systems, system, IT, industry, professional, ...         1380.0
# 286  [Techno, translated, High, Tech, Dance, Tienkn...         6216.0
# 299  [The, timeline, also, known, timeline, way, ax...          328.0
# 307  [The, tree, plants, wooden, trunk, branches, s...         5066.0
# 316  [Wikipedia, English, wikipedia, ˌW, ɪɪpiːpiːː,...         8463.0
#
#      zh_char_count  zh_pct_en_length
# 15          1847.0          0.379651
# 16          1128.0          0.408548
# 17           278.0          0.099428
# 18          1609.0          0.746289
# 29          1867.0          0.646244
# 34           136.0          0.189152
# 37           746.0          0.146879
# 39           843.0          0.230959
# 49          1520.0          0.226967
# 59          3468.0          0.602921
# 61           757.0          0.113374
# 62           225.0          0.086042
# 71           385.0          0.243517
# 72          1574.0          0.716431
# 73           327.0          0.238512
# 83          6042.0          1.093773
# 88          1817.0          0.349827
# 90          3672.0          0.365701
# 93          1136.0          0.294912
# 104           51.0          0.028508
# 106         5838.0          0.817533
# 109         1576.0          0.259296
# 119         3458.0          0.887805
# 126         2594.0          0.200650
# 142          528.0          0.358452
# 144         5326.0          0.673921
# 151           42.0          0.011309
# 154         1437.0          0.204730
# 158         6964.0          0.939557
# 187           32.0          0.005835
# 195          570.0          0.154179
# 197          509.0          0.222855
# 207           59.0          0.087407
# 209          220.0          0.079023
# 216          117.0          0.030693
# 220          219.0          0.131216
# 243         4291.0          0.479174
# 256         4001.0          0.406854
# 257          350.0          0.059850
# 259         1873.0          1.391530
# 267         1606.0          0.806225
# 283           19.0          0.013768
# 286         4660.0          0.749678
# 299           50.0          0.152439
# 307         1224.0          0.241611
# 316         7570.0          0.894482

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
#en_over_words = re.findall(r'\w+', en_parse_text)
[itm[:] for itm in articles['english'].str.findall(r'\w+')] # if len(itm)>0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-2a91eb339204> in <module>
#       1 #en_over_words = re.findall(r'\w+', en_parse_text)
# ----> 2 [itm[:] for itm in articles['english'].str.findall(r'\w+')] # if len(itm)>0]
#
# <ipython-input-93-2a91eb339204> in <listcomp>(.0)
#       1 #en_over_words = re.findall(r'\w+', en_parse_text)
# ----> 2 [itm[:] for itm in articles['english'].str.findall(r'\w+')] # if len(itm)>0]
#
# TypeError: 'float' object is not subscriptable

# %%
articles['english'].apply(lambda x: [item for item in x if item not in stop])
# Out:
# 15     [A, r, c, h, e, l, g,  , r,  , r, c, h, e, l, ...
# 16     [A, r, c, h, e, c, u, r, e,  , (, L, n,  , r, ...
# 17     [A, r, e,  ,  , h, e,  , q, u, n,  , h,  , e, ...
# 18     [T, h, e,  , r,  , r, e,  ,  , v, e, r,  , w, ...
# 34     [B, p, h, c,  ,  , n,  , n, e, r, c, p, l, n, ...
# 37     [B, n, ,,  , l,  , c, l, l, e,  , p, l, n,  , ...
# 39     [A,  , c, r,  , (, r,  , u, b, l, e, ),  ,  , ...
# 49     [A,  , c,  ,  ,  , l, r, g, e,  , h, u, n,  , ...
# 59     [A,  , c, p, u, e, r,  ,  ,  , c, h, n, e,  , ...
# 62     [C, n, r, u, c, n,  ,  ,  , g, e, n, e, r, l, ...
# 71     [T, h, e,  , e, n,  , (, r, e,  , p, r, e, c, ...
# 72     [D, e, n, r, ,,  , l,  , k, n, w, n,  ,  , e, ...
# 73     [A,  , e, g, n,  ,  ,  , p, l, n,  , r,  , p, ...
# 83     [E, r, h,  ,  , h, e,  , h, r,  , p, l, n, e, ...
# 88     [E, u, c, n,  ,  , h, e,  , p, r, c, e,  , f, ...
# 93     [I, n,  , p, h, c, ,,  , e, n, e, r, g,  ,  , ...
# 104    [E, x, p, l, r, n,  ,  , h, e,  , c,  , f,  , ...
# 109    [F,  ,  , n,  , u, b, n, c, e,  , c, n, u, e, ...
# 126    [G, r, e, e, c, e,  , (, G, r, e, e, k, :,  , ...
# 142    [I, u, n, l, g,  ,  ,  , b, r, n, c, h,  , f, ...
# 144    [I, n,  , (, H, n, :,  , B, h, ā, r, ), ,,  , ...
# 151    [I, n, n, v, n,  ,  , h, e,  , p, r, c, c, l, ...
# 158    [A,  , l, n, g, u, g, e,  ,  ,  , r, u, c, u, ...
# 187    [M, n, n, g,  ,  , h, e,  , e, x, r, c, n,  , ...
# 195    [N, u, r, e, ,,  , n,  , h, e,  , b, r, e,  , ...
# 197    [N, e, u, r, c, e, n, c, e,  , (, r,  , n, e, ...
# 207    [P, r, l, g,  ,  , h, e,  , u,  , f,  , p, r, ...
# 209    [P, h, l, g,  ,  , h, e,  , u,  , f,  , h, e, ...
# 216    [P, h, r, c,  ,  , h, e,  , c, l, n, c, l,  , ...
# 220    [P, h, l, g,  , (, ;,  , f, r,  , A, n, c, e, ...
# 243    [P, c, h, l, g,  ,  , h, e,  , c, e, n, c, e, ...
# 257    [S, c, e, n, c, e,  , (, f, r,  , h, e,  , L, ...
# 283    [A,  , e,  ,  ,  , g, r, u, p,  , f,  , n, e, ...
# 286    [T, e, c, h, n,  ,  ,  , g, e, n, r, e,  , f, ...
# 299    [A,  , e, l, n, e,  ,  ,  , p, l,  , f,  ,  , ...
# 307    [I, n,  , b, n, ,,  ,  , r, e, e,  ,  ,  , p, ...
# 316    [W, k, p, e,  , (,  , (, l, e, n, ),  , w, k, ...
# Name: english, dtype: object

# %%
articles = articles['english'].apply(lambda row: row["english"].str.findall(r'\w+'))
#result = df.apply(lambda row: row["Name"] + " , " + str(row["TotalMarks"]) + " , " +  row["Grade"], axis = 1)
#http://net-informations.com/ds/pd/iterate.htm
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-5e2f5ce21ea3> in <module>
# ----> 1 articles = articles['english'].apply(lambda row: row["english"].str.findall(r'\w+'))
#       2 #result = df.apply(lambda row: row["Name"] + " , " + str(row["TotalMarks"]) + " , " +  row["Grade"], axis = 1)
#       3 #http://net-informations.com/ds/pd/iterate.htm
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-34-5e2f5ce21ea3> in <lambda>(row)
# ----> 1 articles = articles['english'].apply(lambda row: row["english"].str.findall(r'\w+'))
#       2 #result = df.apply(lambda row: row["Name"] + " , " + str(row["TotalMarks"]) + " , " +  row["Grade"], axis = 1)
#       3 #http://net-informations.com/ds/pd/iterate.htm
#
# TypeError: string indices must be integers

# %%
#combine these two somehow
articles = articles['english'].apply(lambda row: row["english"].str.findall(r'\w+'))
[itm[:] for itm in articles['english'].str.findall(r'\w+')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-7721e747f754> in <module>
#       1 #combine these two somehow
# ----> 2 articles = articles['english'].apply(lambda row: row["english"].str.findall(r'\w+'))
#       3 [itm[:] for itm in articles['english'].str.findall(r'\w+')]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-36-7721e747f754> in <lambda>(row)
#       1 #combine these two somehow
# ----> 2 articles = articles['english'].apply(lambda row: row["english"].str.findall(r'\w+'))
#       3 [itm[:] for itm in articles['english'].str.findall(r'\w+')]
#
# TypeError: string indices must be integers

# %%
// Load stop words from file
Set<String> stopWords = new TreeSet<>(String.CASE_INSENSITIVE_ORDER);
stopWords.addAll(Files.readAllLines(Paths.get("G:\\stopwords.txt")));

// Get text and split into words
String text = request.getParameter("textblock");
List<String> wordsList = new ArrayList<>(Arrays.asList(
        text.replaceAll("[\\s,;]+", " ").trim().split(" ")));

// Remove stop words from list of words
wordsList.removeAll(stopWords);

# %%
articles['en_char_count']  = articles['english'].str.len()
articles['zh_char_count']  = articles['chinese'].str.len()
articles.head()
# Out:
#            topic english_title  \
# 15   Archaeology   Archaeology
# 16  Architecture  Architecture
# 17          area          Area
# 18          arts      The arts
# 29  Biochemistry  Biochemistry
#
#                                               english  chinese_title  \
# 15  [Archaeology, archeology, study, human, activi...    archeology
# 16  [Architecture, Latin, architectura, Greek, ἀρχ...      building
# 17  [Area, quantity, expresses, extent, two, dimen...          Area
# 18  [The, arts, wide, range, human, practices, cre...   Art species
# 29  [Biochemistry, biological, chemistry, study, c...  Biochemistry
#
#                                               chinese  en_char_count  \
# 15  [Archaeological, English, Archaeology, Archeol...           4865
# 16  [Building, usually, referring, part, behavior,...           2761
# 17  [Area, group, established, 1972, formerly, gua...           2796
# 18  [Art, manifestation, performance, affected, cu...           2156
# 29  [Biochemistry, English, Biochemistry, also, ma...           2889
#
#     zh_char_count  zh_pct_en_length
# 15           1847          0.379651
# 16           1128          0.408548
# 17            278          0.099428
# 18           1609          0.746289
# 29           1867          0.646244

# %%
articles['en_char_count'].mean()
# Out:
# 4469.586956521739

# %%
articles['zh_char_count'].mean()
# Out:
# 1838.2826086956522

# %%
1786/4432
# Out:
# 0.4029783393501805

# %%
articles['zh_pct_en_count'] = articles['zh_char_count'] / articles['en_char_count']
articles.head()
# Out:
#            topic english_title  \
# 15   Archaeology   Archaeology
# 16  Architecture  Architecture
# 17          area          Area
# 18          arts      The arts
# 29  Biochemistry  Biochemistry
#
#                                               english  chinese_title  \
# 15  [Archaeology, archeology, study, human, activi...    archeology
# 16  [Architecture, Latin, architectura, Greek, ἀρχ...      building
# 17  [Area, quantity, expresses, extent, two, dimen...          Area
# 18  [The, arts, wide, range, human, practices, cre...   Art species
# 29  [Biochemistry, biological, chemistry, study, c...  Biochemistry
#
#                                               chinese  en_char_count  \
# 15  [Archaeological, English, Archaeology, Archeol...           4865
# 16  [Building, usually, referring, part, behavior,...           2761
# 17  [Area, group, established, 1972, formerly, gua...           2796
# 18  [Art, manifestation, performance, affected, cu...           2156
# 29  [Biochemistry, English, Biochemistry, also, ma...           2889
#
#     zh_char_count  zh_pct_en_length  zh_pct_en_count
# 15           1847          0.379651         0.379651
# 16           1128          0.408548         0.408548
# 17            278          0.099428         0.099428
# 18           1609          0.746289         0.746289
# 29           1867          0.646244         0.646244

# %%
import matplotlib as plt
import seaborn as sns

# %%
sns.histplot(x = 'en_char_count', data = articles, bins = 20)
#plt.xticks(rotation = 50)
fig = plt.figure(figsize = (24,8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-1c173fee846a> in <module>
#       1 sns.histplot(x = 'en_char_count', data = articles, bins = 20)
#       2 #plt.xticks(rotation = 50)
# ----> 3 fig = plt.figure(figsize = (24,8))
#
# TypeError: 'module' object is not callable

# %%
sns.histplot(x = 'zh_char_count', data = articles, bins = 20)
#plt.xticks(rotation = 50)
fig = plt.figure(figsize = (24,8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-84ea6b226c07> in <module>
#       1 sns.histplot(x = 'zh_char_count', data = articles, bins = 20)
#       2 #plt.xticks(rotation = 50)
# ----> 3 fig = plt.figure(figsize = (24,8))
#
# TypeError: 'module' object is not callable

# %%
articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 15 to 316
# Data columns (total 8 columns):
# topic               46 non-null object
# english_title       46 non-null object
# english             46 non-null object
# chinese_title       46 non-null object
# chinese             46 non-null object
# en_char_count       46 non-null int64
# zh_char_count       46 non-null int64
# zh_pct_en_length    46 non-null float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.2+ KB

# %%
sns.histplot(x = 'zh_pct_en_count', data = articles, bins = 20)
#plt.xticks(rotation = 50)
fig = plt.figure(figsize = (24,8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-67c7f334ecc5> in <module>
#       1 sns.histplot(x = 'zh_pct_en_count', data = articles, bins = 20)
#       2 #plt.xticks(rotation = 50)
# ----> 3 fig = plt.figure(figsize = (24,8))
#
# TypeError: 'module' object is not callable
