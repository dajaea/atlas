# %%
import pandas as pd
import numpy as np
import json
import glob

# %% [markdown]
# import requests
# return requests.get(url).json()

# %%
folder = (glob.glob('../data/matched_content_more_mvp2/*'))

# %% [markdown]
# #all_folder = folder[:]
# preview = folder[:]
# #print(preview)

# %% [markdown]
# title_columns = ["english_title", "chinese_title"]
# data = []
# with open(filename, 'r') as f:
#     objects = json(f, data)
#     for row in objects:
#         selected_row = []
#         for item in title_columns:
#             new_row.append(row[title_columns.index(item)])
#             data.append(new_row)

# %% [markdown]
# for file in preview:
#     for value in open(file, 'r'):
#         print(json.loads(value))

# %% [markdown]
# preview_list = []
# for file in preview:
#     with open(file, 'r') as f:
#         article = json.load(f)
#     preview_list.append(article)

# %% [markdown]
# preview_frame = pd.DataFrame(preview_list).replace(r'^\s*$', np.nan, regex=True)
# #.replace('', None)
# #preview_frame.loc[0, 'chinese']
# preview_frame.info()

# %% [markdown]
# preview_frame.dropna()

# %% [markdown]
# #def print_title():
#     for file in preview:
#         open(file, 'r'):
#             print(json.loads(file['english_title'])

# %% [markdown]
# for file in preview:
#      = json.loads(file)

# %% [markdown]
# data_list = []
# for file in os.listdir(base_dir):
#
#     #If file is a json, construct it's full path and open it, append all json data to list
#     if 'json' in file:
#         json_path = os.path.join(base_dir, file)
#         json_data = pd.read_json(json_path, lines=True)
#         data_list.append(json_data)
#
# print(data_list)

# %% [markdown]
# with open(f'../data/content_{topic}.json', 'w') as fi:
#         json.dump({
#
#             'topic':topic,
#             'english_title':en_title,
#             'english':en_topic_content,
#             'chinese_title':zh_title,
#             'chinese':zh_topic_content
#
#         }, fi)
#
# for topic in en_all_topics:
#
#     try:
#         article = wiki.page(topic, auto_suggest = False)
#         en_topic_content = (article.content)
#         en_title = article.title
#     except:
#         en_topic_content = ''
#         en_title = ''
#
#     wiki.set_lang("zh")
#     try:
#         article = wiki.page(topic, auto_suggest = False)
# #       zh_topic_content = translator.translate(article.content, lang_tgt = 'en')
#         zh_title = translator.translate(article.title, lang_tgt = 'en')
#
#         remain_text = article.content
#         zh_topic_content = ''
#
#         while len(remain_text) > 0:
#             zh_topic_content += translator.translate(remain_text[0:4999])
#             remain_text = remain_text[4999:]
#     except:
#         zh_topic_content = ''
#         zh_title = ''

# %% [markdown]
# use ijson to iteratively process the JSON file

# %%
article_list = []

# %%
for file in folder:
    try:
        with open(file, 'r') as f:
            article = json.load(f)
        article_list.append(article)
    except:
        continue

# %%
articles = pd.DataFrame(article_list).replace(r'^\s*$', np.nan, regex = True)
articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910 entries, 0 to 909
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   topic          910 non-null    object
#  1   english_title  877 non-null    object
#  2   english        877 non-null    object
#  3   chinese_title  781 non-null    object
#  4   chinese        781 non-null    object
# dtypes: object(5)
# memory usage: 35.7+ KB

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
articles = articles.dropna()

# %%
articles.head(200)
# Out:
#                                          topic  \
# 0                                      .travel
# 1                      1965 Formula One season
# 2                                           4G
# 3                             A Dark Traveling
# 4                           A3 problem solving
# ..                                         ...
# 241                         Government revenue
# 242  Government spending in the United Kingdom
# 243   Government spending in the United States
# 244                        Government spending
# 245                           Grading (tumors)
#
#                                  english_title  \
# 0                                      .travel
# 1                      1965 Formula One season
# 2                                           4G
# 3                             A Dark Traveling
# 4                           A3 problem solving
# ..                                         ...
# 241                         Government revenue
# ...

# %%
len(articles)
# Out:
# 754

# %% [markdown]
# #en_over_words = re.findall(r'\w+', en_parse_text)
# [itm[:] for itm in articles['english'].str.findall(r'\w+')] # if len(itm)>0]

# %% [markdown]
# articles['english'].apply(lambda x: [item for item in x if item not in stop])

# %% [markdown]
# articles = articles['english'].apply(lambda row: row["english"].str.findall(r'\w+'))
# #result = df.apply(lambda row: row["Name"] + " , " + str(row["TotalMarks"]) + " , " +  row["Grade"], axis = 1)
# #http://net-informations.com/ds/pd/iterate.htm

# %% [markdown]
# #combine these two somehow
# articles = articles['english'].apply(lambda row: row["english"].str.findall(r'\w+'))
# [itm[:] for itm in articles['english'].str.findall(r'\w+')]

# %% [markdown]
# // Load stop words from file
# Set<String> stopWords = new TreeSet<>(String.CASE_INSENSITIVE_ORDER);
# stopWords.addAll(Files.readAllLines(Paths.get("G:\\stopwords.txt")));
#
# // Get text and split into words
# String text = request.getParameter("textblock");
# List<String> wordsList = new ArrayList<>(Arrays.asList(
#         text.replaceAll("[\\s,;]+", " ").trim().split(" ")));
#
# // Remove stop words from list of words
# wordsList.removeAll(stopWords);

# %%
articles['en_char_count']  = articles['english'].str.len()
articles['zh_char_count']  = articles['chinese'].str.len()
articles.head()
# Out:
#                      topic            english_title  \
# 0                  .travel                  .travel
# 1  1965 Formula One season  1965 Formula One season
# 2                       4G                       4G
# 3         A Dark Traveling         A Dark Traveling
# 4       A3 problem solving       A3 problem solving
#
#                                              english chinese_title  \
# 0  [The, domain, name, travel, top, level, domain...      .travel
# 1  [The, 1965, Formula, One, season, 19th, season...       Braham
# 2  [4G, fourth, generation, broadband, cellular, ...          Chg
# 3  [A, Dark, Traveling, science, fantasy, novel, ...    Tom Patty
# 4  [A3, problem, solving, structured, problem, so...    A3 report
#
#                                              chinese  en_char_count  \
# 0  [Travel, one, top, level, domains, Internet, u...            152
# 1  [Racing, Sports, Development, Co, Ltd, English...            241
# ...

# %%
articles['en_char_count'].mean()
# Out:
# 1312.838196286472

# %%
articles['zh_char_count'].mean()
# Out:
# 793.3183023872679

# %%
1786/4432
# Out:
# 0.4029783393501805

# %%
articles['zh_pct_en_count'] = articles['zh_char_count'] / articles['en_char_count']
articles.head()
# Out:
#                      topic            english_title  \
# 0                  .travel                  .travel
# 1  1965 Formula One season  1965 Formula One season
# 2                       4G                       4G
# 3         A Dark Traveling         A Dark Traveling
# 4       A3 problem solving       A3 problem solving
#
#                                              english chinese_title  \
# 0  [The, domain, name, travel, top, level, domain...      .travel
# 1  [The, 1965, Formula, One, season, 19th, season...       Braham
# 2  [4G, fourth, generation, broadband, cellular, ...          Chg
# 3  [A, Dark, Traveling, science, fantasy, novel, ...    Tom Patty
# 4  [A3, problem, solving, structured, problem, so...    A3 report
#
#                                              chinese  en_char_count  \
# 0  [Travel, one, top, level, domains, Internet, u...            152
# 1  [Racing, Sports, Development, Co, Ltd, English...            241
# ...

# %%
import matplotlib as plt
import seaborn as sns
from matplotlib import *
import sys
from pylab import *

# %%
sns.histplot(x = 'en_char_count', data = articles, bins = 50)
#plt.xticks(rotation = 50)
#fig = plt.figure(figsize = (24,8))
plt.xlabel("Character Range")
plt.ylabel("Articles")
plt.title("English Character Count")
plt.show(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0191ba9c702d> in <module>
#       5 plt.ylabel("Articles")
#       6 plt.title("English Character Count")
# ----> 7 plt.show(fig)
#
# NameError: name 'fig' is not defined

# %%
ax = sns.histplot(x = 'zh_char_count', data = articles, bins = 70)
#plt.xticks(rotation = 50)
#plt.figure(figsize = (24,8))
ax.set(xlabel="X Label", ylabel = "Y Label")
plt.xlabel("Character Range")
plt.ylabel("Articles")
plt.title("Mandarin Character Count")
plt.show(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8560947ac634> in <module>
#       6 plt.ylabel("Articles")
#       7 plt.title("Mandarin Character Count")
# ----> 8 plt.show(fig)
#
# NameError: name 'fig' is not defined

# %%
articles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 754 entries, 0 to 909
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   topic            754 non-null    object
#  1   english_title    754 non-null    object
#  2   english          754 non-null    object
#  3   chinese_title    754 non-null    object
#  4   chinese          754 non-null    object
#  5   en_char_count    754 non-null    int64
#  6   zh_char_count    754 non-null    int64
#  7   zh_pct_en_count  754 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 53.0+ KB

# %%
articles['zh_pct_en_count'] = articles['zh_pct_en_count'].round(decimals = 3)

# %%
articles.head()
# Out:
#                      topic            english_title  \
# 0                  .travel                  .travel
# 1  1965 Formula One season  1965 Formula One season
# 2                       4G                       4G
# 3         A Dark Traveling         A Dark Traveling
# 4       A3 problem solving       A3 problem solving
#
#                                              english chinese_title  \
# 0  [The, domain, name, travel, top, level, domain...      .travel
# 1  [The, 1965, Formula, One, season, 19th, season...       Braham
# 2  [4G, fourth, generation, broadband, cellular, ...          Chg
# 3  [A, Dark, Traveling, science, fantasy, novel, ...    Tom Patty
# 4  [A3, problem, solving, structured, problem, so...    A3 report
#
#                                              chinese  en_char_count  \
# 0  [Travel, one, top, level, domains, Internet, u...            152
# 1  [Racing, Sports, Development, Co, Ltd, English...            241
# ...

# %%
import numpy as np

articles = articles[np.isfinite(articles['zh_pct_en_count'])]

articles.head()
# Out:
#                      topic            english_title  \
# 0                  .travel                  .travel
# 1  1965 Formula One season  1965 Formula One season
# 2                       4G                       4G
# 3         A Dark Traveling         A Dark Traveling
# 4       A3 problem solving       A3 problem solving
#
#                                              english chinese_title  \
# 0  [The, domain, name, travel, top, level, domain...      .travel
# 1  [The, 1965, Formula, One, season, 19th, season...       Braham
# 2  [4G, fourth, generation, broadband, cellular, ...          Chg
# 3  [A, Dark, Traveling, science, fantasy, novel, ...    Tom Patty
# 4  [A3, problem, solving, structured, problem, so...    A3 report
#
#                                              chinese  en_char_count  \
# 0  [Travel, one, top, level, domains, Internet, u...            152
# 1  [Racing, Sports, Development, Co, Ltd, English...            241
# ...

# %%
sns.histplot(x = 'zh_pct_en_count', data = articles, bins = 20)
#plt.xticks(rotation = 50)
#fig = plt.figure(figsize = (24,8))
plt.xlabel("Matched Article Length")
plt.ylabel("Articles")
plt.title("Mandarin to English Length")
plt.show(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-9c82e2df664e> in <module>
#       5 plt.ylabel("Articles")
#       6 plt.title("Mandarin to English Length")
# ----> 7 plt.show(fig)
#
# NameError: name 'fig' is not defined

# %%
from sklearn.metrics import jaccard_score

# %% [markdown]
# articles['jacc_sim'] = jaccard_score(articles['english'], articles['chinese'])
# articles.head()
#
# ValueError: You appear to be using a legacy multi-label data representation. Sequence of sequences are no longer supported; use a binary array or sparse matrix instead - the MultiLabelBinarizer transformer can convert to this format.

# %% [markdown]
# ### Jaccard

# %%
doc1 = ['Archaeology', 'archeology', 'study', 'human']
doc2 = ['Archaeological', 'English', 'Archaeology']

# %%
doc1 = 'Archaeology archeology study human'
doc2 = 'Archaeological English Archaeology'

# %%
doc1 = 'I am really close to the other sentence'
doc2 = 'I really am close the to other sentences'

# %%
def Jaccard_Similarity(doc1, doc2): 
    
    # List the unique words in a document
    words_doc1 = set(doc1.lower().split()) 
    words_doc2 = set(doc2.lower().split())
    
    # Find the intersection of words list of doc1 & doc2
    intersection = words_doc1.intersection(words_doc2)

    # Find the union of words list of doc1 & doc2
    union = words_doc1.union(words_doc2)
        
    # Calculate Jaccard similarity score 
    # using length of intersection set divided by length of union set
    return float(len(intersection)) / len(union)

# %%
Jaccard_Similarity(doc1, doc2)

# %%
list = [4, 'hello', 1, 'how', 1, 2,]
mystring = ' '.join(map(str, list))
print(mystring)

# %%
list = None

# %% [markdown]
# # !

# %%
articles['en_string'] = [' '.join(map(str, l)) for l in articles['english']]
articles.head()
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                      topic            english_title  \
# 0                  .travel                  .travel
# 1  1965 Formula One season  1965 Formula One season
# 2                       4G                       4G
# 3         A Dark Traveling         A Dark Traveling
# 4       A3 problem solving       A3 problem solving
#
#                                              english chinese_title  \
# 0  [The, domain, name, travel, top, level, domain...      .travel
# 1  [The, 1965, Formula, One, season, 19th, season...       Braham
# ...

# %%
articles['zh_string'] = [' '.join(map(str, l)) for l in articles['chinese']]
articles.head()
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                      topic            english_title  \
# 0                  .travel                  .travel
# 1  1965 Formula One season  1965 Formula One season
# 2                       4G                       4G
# 3         A Dark Traveling         A Dark Traveling
# 4       A3 problem solving       A3 problem solving
#
#                                              english chinese_title  \
# 0  [The, domain, name, travel, top, level, domain...      .travel
# 1  [The, 1965, Formula, One, season, 19th, season...       Braham
# ...

# %%
articles['jacc_sim'] = articles.apply(lambda row: Jaccard_Similarity(row['en_string'], row['zh_string']), axis = 1)
articles.head()
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                      topic            english_title  \
# 0                  .travel                  .travel
# 1  1965 Formula One season  1965 Formula One season
# 2                       4G                       4G
# 3         A Dark Traveling         A Dark Traveling
# 4       A3 problem solving       A3 problem solving
#
#                                              english chinese_title  \
# 0  [The, domain, name, travel, top, level, domain...      .travel
# 1  [The, 1965, Formula, One, season, 19th, season...       Braham
# ...

# %%
pd.set_option('display.max_rows', 100)

# %%
jacc_low = articles[['english_title', 'zh_pct_en_count', 'jacc_sim']].sort_values('jacc_sim', ascending = True).round(decimals = 3)
jacc_low = jacc_low.rename(columns = {'english_title': 'Matched Article', 'zh_pct_en_count': 'Length Ratio', 'jacc_sim': 'Similarity'})
jacc_low.head(100)
# Out:
#                                        Matched Article  Length Ratio  \
# 273                                    Health facility         0.050
# 24                                        All Included         0.284
# 522                      List of works by Michelangelo       164.703
# 535                                     Magnet fishing         0.030
# 471       List of countries by natural gas consumption        22.333
# 605                     Occupational safety and health         0.005
# 76                                         Brad Arnold         2.365
# 130                                        David Hobby         0.354
# 506                 List of pirate films and TV series       174.405
# 774                         Taxing and Spending Clause         0.006
# 282                                         Health Net         0.019
# 786                                       Telus Health         0.104
# 63                  Batteries Not Included (TV series)        73.731
# ...

# %%
jacc_high = articles[['english_title', 'zh_pct_en_count', 'jacc_sim']].sort_values('jacc_sim', ascending = False).round(decimals = 3)
jacc_high = jacc_high.rename(columns = {'english_title': 'Matched Article', 'zh_pct_en_count': 'Length Ratio', 'jacc_sim': 'Similarity'})
jacc_high.head(100)
# Out:
#                                        Matched Article  Length Ratio  \
# 556                           Medicare (United States)         0.936
# 600                              Nonlinear programming         1.037
# 264           Health care finance in the United States         0.998
# 75                                     Boom Technology         0.914
# 29                                    Amkor Technology         0.992
# 808                                        Time travel         0.932
# 228                                Genetic engineering         0.796
# 269                                   Health economics         0.665
# 639                          Philosophy of information         0.730
# 111                                   Computer science         0.884
# 644                                           Podocyte         0.889
# 575  Ministry of Science, Technology and Innovation...         1.631
# 563                                      Metamyelocyte         1.468
# ...

# %%
articles.sort_values('jacc_sim', ascending = True)
# Out:
#                                             topic  \
# 273                               Health facility
# 24                                   All Included
# 522                 List of works by Michelangelo
# 535                                Magnet fishing
# 471  List of countries by natural gas consumption
# ..                                            ...
# 29                               Amkor Technology
# 75                                Boom Technology
# 264      Health care finance in the United States
# 600                         Nonlinear programming
# 556                      Medicare (United States)
#
#                                     english_title  \
# 273                               Health facility
# 24                                   All Included
# 522                 List of works by Michelangelo
# 535                                Magnet fishing
# 471  List of countries by natural gas consumption
# ..                                            ...
# ...

# %%
print(articles.loc[158, 'en_string'])
# Out:
# The economy United States highly developed mixed economy It world largest economy nominal GDP net wealth second largest purchasing power parity PPP It world fifth highest per capita GDP nominal seventh highest per capita GDP PPP 2021 The United States technologically powerful economy world firms near forefront technological advances especially artificial intelligence computers pharmaceuticals medical aerospace military equipment The U S dollar currency used international transactions world foremost reserve currency backed economy military petrodollar system linked eurodollar large U S treasuries market Several countries use official currency others de facto currency The largest U S trading partners China Canada Mexico India Japan Germany South Korea United Kingdom France Taiwan The U S world largest importer second largest exporter It free trade agreements several nations including USMCA Australia South Korea Israel several others effect negotiation The nation economy fueled abundant
# ...

# %%
print(articles.loc[158, 'zh_string'])
# Out:
# The Second Amendment US Constitution English Second Amendment United States constitude one US Rights Act officially passed December 15 1791 It protects people rights hold carry weapons citizens Civil rights defense History The first batch European immigrants reached May Flower arrived North American continent weapons relying firearms land land surroundings beast Indians weapons became tool everyone Since 13th states North America gradually formed standing government forces states rely militia conduct self defense state government gradually involved weapon management state governments even punish arms With start independence war influence militia expanded weapons civilians British combat 8 years successfully independent war After founding People Republic China Holding Carrying Weapons written naturally written 1791 Rights Act 1789 US Constitution written naturally 1791 In order limit strong autocratic government prevent government power infringe violation civil power impart weapon cit
# ...
